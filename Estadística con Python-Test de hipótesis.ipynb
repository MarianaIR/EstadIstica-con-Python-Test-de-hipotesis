# %% [markdown]
# # <font color=green>1. DESCRIPCIÓN Y LECTURA DE LOS DATOS</font>
# ***

# %% [markdown]
# **Encuesta Nacional de Hogares -- 2015**

# %% [markdown]
# La <b> Encuesta Nacional de Hogares (PNDA, del portugués Pesquisa Nacional por Amostra de Domicílios)</b> anualmente investiga, de forma permanente, las características generales de la población, educación, trabajo, ingresos y vivienda, y otras con frecuencia variable, de acuerdo con las necesidades de información del país, tales como las características de migración, fecundidad, nupcialidad, salud, seguridad alimentaria, entre otros temas. La recopilación de estas estadísticas constituye, durante los 49 años de realización de la investigación, **un importante instrumento para la formulación, validación y evaluación de políticas orientadas al desarrollo socioeconómico y a la mejora de las condiciones de vida en Brasil**.

# %% [markdown]
# ## Fuente

# %% [markdown]
# https://www.ibge.gov.br/estatisticas/sociais/populacao/9127-pesquisa-nacional-por-amostra-de-domicilios.html?=&t=microdados

# %% [markdown]
# ## Variables

# %% [markdown]
# > ### Renta
# > ***
#
# Ingreso mensual del jefe del hogar.
#
# > ### Edad
# > ***
#
# Edad (en años) del jefe del hogar.
#
# > ### Altura (construida)
# > ***
#
# Altura (en metros) del jefe del hogar.
#
# > ### UF (Unidad de federación)
# > ***
#
# |Código|Descripción|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descripción|
# |---|---|
# |0|Masculino|
# |1|Femenino|
#
# > ### Años de estudio
# > ***
#
# |Código|Descripción|
# |---|---|
# |1|Sin instrucción o menos de 1 año|
# |2|1 año|
# |3|2 años|
# |4|3 años|
# |5|4 años|
# |6|5 años|
# |7|6 años|
# |8|7 años|
# |9|8 años|
# |10|9 años|
# |11|10 años|
# |12|11 años|
# |13|12 años|
# |14|13 años|
# |15|14 años|
# |16|15 años o más|
# |17|No determinados|
# ||No aplica|
#
# > ### Color
# > ***
#
# |Código|Descripción|
# |---|---|
# |0|Indigena|
# |2|Blanca|
# |4|Negra|
# |6|Amarilla|
# |8|Parda|
# |9|Sin declaración|

# %% [markdown]
# <font color='red'>Observación</font>
# ***
# > Se realizaron los siguientes tratamientos sobre los datos originales:
# > 1. Se eliminaron los registros en los que la <b>Renta</b> no era válida (999 999 999 999);
# > 2. Se eliminaron los registros en los que la <b>Renta</b> era missing;
# > 3. Sólo se consideraron los registros de las  <b>personas de referencia</b> de cada hogar (responsables del hogar).

# %% [markdown]
# ## Importando Bibliotecas y leyendo la base de datos
#
# https://pandas.pydata.org/

# %%
# 1°)
import pandas as pd
import numpy as np

# %%
datos = pd.read_csv("datos.csv")

# %%
datos.head()
# Out:
#    UF  Sexo  Edad  Color  Anos de Estudio  Renta    Altura
# 0  11     0    23      8               12    800  1.603808
# 1  11     1    23      2               12   1150  1.739790
# 2  11     1    35      8               15    880  1.760444
# 3  11     0    46      2                6   3500  1.783158
# 4  11     1    47      8                9    150  1.690631

# %% [markdown]
# ## Algunas preguntas que pueden ser de interés
# > 1. ¿La variable altura se distribuye como una normal?
# > 2. ¿Los jefes del hogar tienen en promedio 1,70 cm de altura?
# > 3. ¿Las mujeres ganan menos que los hombres?
#
#
# - Este tipo de preguntas son muy importante, porque a partir de ellas podemos escoger la METODOLOGIA adecuada de Estadistica para cada caso.

# %% [markdown]
# # <font color=green>2. PRUEBA DE HIPÓTESIS</font>
#
# ***

# %% [markdown]
# Una prueba de hipótesis estadística es un procedimiento que permite decidir entre dos hipótesis opuestas: <b>Hipótesis nula</b> $(H_0)$  y la <b>Hipótesis alterna</b> $(H_1)$, las cuales conjeturan sobre alguna caraterística desconocida de la población de interés.
#
# Para realizar este procedimiento se retira una muestra aleatoria de la población bajo estudio y con base en las evidencias de esa muestra se toma la decisión de rechazar o no rechazar $H_0$.<font color='red'> Note que la decisión es sobre $H_0$</font>!

# %% [markdown]
# ## **Entendiendo $H_0$ y $H_1$** (Analogia con proceso judiacial)
# Considere que hay una persona que está siendo juzgada, sabemos que por ley una persona es INOCENTE hasta que se demuestre lo contrario:

# %% [markdown]
# ***HIPOTESIS NULA***, $H_0$:  La persona es **inocente**.
#
# ***HIPOTESIS ALTERNA***, $H_1$: La persona es **culpable**.
#
#
#
# - Lo que afirmamos lo colocamos en la HIPOTESIS NULA y lo que investigamos, indagamos, etc lo colocamos en la HIPOTESIS ALTERNA. La razon de rechazar $H_0$, significa en este caso el juicio ha sido capaz de presentar suficiente evidencia par agarantizar un veredicto culpable $H_1$. Por otra parte si el juicio NO representa evidencia sustancial, la persona es declarada inocente $H_0$. Pero esa desicion NO implica que esa persona sea necesariamente inocente, solo nos intuye que hay una falta de pruebas contundentes para condenarla.
#
# - En el contexto ESTADISTICO la desicion se basa en las evidencias que se encuentra o proporciona en una MUESTRA. Cuando se toma una desicion con $H_0$, se pueden cometer ERORRES --->

# %% [markdown]
# ## **Errores Inferenciales** (ERROR TIPO I y ERROR TIPO II)
#
# Un proceso inferencial siempre se encuentra sujeto a errores.

# %% [markdown]
#  <b>Error Tipo I</b>: Rechazar $H_0$ siendo $H_0$ verdadera.
#
# > *Ejemplo: La persona es condenada a pesar de que realmente inocente*.
#
#
#
#  <b>Error Tipo II</b>: No rechazar $H_0$ siendo $H_0$ falsa.
#
# >*Ejemplo: La persona es absuelta a pesar de ser culpable*.
#
#
# - Debemos medir la posibilidad de comoter ERRORES.

# %% [markdown]
# <b>Notación de los errores </b>
#
# P(Error Tipo I) = $\alpha$  (<b>Nivel de significancia </b>), P = Probabilidad de error tipo I
#
# P(Error Tipo II) = $\beta$, (siendo $1-\beta$ la <b>Potencia</b> )

# %% [markdown]
# El objetivo principal es proponer algún procedimiento de prueba de hipótesis que minimice los dos errores. Sin embargo, **en la práctica, solo se controla el error de tipo I** y generalmente su probabilidad es fijada en 0,05 o 0,01.
#
# - ERROR TIPO I mucho mas serio que el ERROR TIPO II, ejemplo: es peor condenar a un INOCENTE que dejar libre a un CULPABLE.

# %% [markdown]
# ## **Criterio para decidir si se rechaza o no $H_0$**

# %% [markdown]
# <b>Región Crítica</b>: Valores de la **estadística de prueba** que conllevan al rechazo de $H_0$.
#
# <b>$p$-valor</b>: Menor nivel de significancia con el cuál rechazamos $H_0$ siendo aplicado después que el experimento fue realizado.
# >- Si $p$-valor $\leq \alpha$ rechazamos $H_0$.
#
# >- Si $p$-valor $> \alpha$ no rechazamos $H_0$.

# %% [markdown]
# ## <font color=green>2.1 Prueba de normalidad </font>
#
# ***
#
#
# ¿La variable altura se distribuye como una normal? RTA= SI

# %% [markdown]
# **Es una prueba que nos permite determinar si un conjunto de datos proviene o no de una distribución normal.**

# %% [markdown]
# Hipótesis de interés
#
# $H_0$:  La muestra proviene de una distribución normal.
#
# $H_1$: La muestra no proviene de una distribución normal.

# %% [markdown]
# **Importando biblioteca**
#
# Existen varias pruebas de NORMALIDAD, pero vamos sa utilizar SCIPY.STATS.NORMALTEST, esta prueba esta basada en DAGOSTINO y PEARSONS.
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html

# %%
# 1°) Invocamos la FUNCION e importamos BIBLIOTECA --->

from scipy.stats import normaltest

# %% [markdown]
# La función **normaltest** prueba la hipótesis nula $H_0$ de que la muestra proviene de una distribución normal.

# %% [markdown]
# <font color='red'>Rechazamos $H_0$ si el $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# Fijando el nivel de significancia $(\alpha)$

# %%
# 2°) Definimos el valor de alpha --->
significancia = 0.05

# %% [markdown]
# ### **Probando normalidad en la variable Renta**

# %% [markdown]
# **Inspección visual**

# %%
# 3°) Primeros vemos se comporta esta VARIABLE con un HISTOGRAMA, antes de aplicar la funcion --->

datos.Renta.hist(bins=50)

# VEMOS QUE LA DISTRIBUCION DE LA MUESTRA DE LA RENTA ES ASIMETRICA, LO USUAL ES QUE EL COMPORTAMIENTO SEA
# EN FORMA DE CAMPANA Y AQUI NO LA TENEMOS, TENEMOS UNA SOSPECHA DE QUE LA VARIABLE RENTA NO TIENE UNA
# DISTRIBUCION NORMAL!
# Out:
# <Axes: >

# %% [markdown]
# **Establecemos las hipótesis**
#
# Entonces para tener una prueba de eso hacemos formalmente una prueba de HIPOTESIS para ver si eso que mencianamos en el Histograma es cierto o NO!

# %% [markdown]
# $H_0$:  La muestra de la renta de los jefes del hogar proviene de una distribución normal.
#
# $H_1$: La muestra de la renta de los jefes del hogar no proviene de una distribución normal.

# %%
# 4°) Aplicamos la FUNCION --->

normaltest(datos.Renta) # Nos devuelve la estadistica de prueba y el pvalor.
# Out:
# NormaltestResult(statistic=152380.75803960307, pvalue=0.0)

# %%
# 5°) Separamos los valores de arriba para que quede mas claro --->

stats_test, p_valor = normaltest(datos.Renta)
print(stats_test)
print(p_valor)
# Out:
# 152380.75803960307
# 0.0

# %% [markdown]
# <font color='red'> Rechazamos la Hipotesis $H_0$ si el $p$-valor $\leq \alpha$ </font>

# %%
# 6°)
p_valor <= significancia
# Nos devuelve TRUE, El p_valor es menor o igual a la Significancia!
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto tenemos suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Con un nivel de significancia del 5% podemos concluir que la muestra de la renta de los jefes del hogar NO proviene de una distribución normal.</font>

# %% [markdown]
# ### **Probando normalidad en la variable Altura**

# %% [markdown]
# **Inspección visual**

# %%
# 7°) Vemos el Histograma de variable ALTURA --->

datos.Altura.hist(bins=50)

# LA ALTURA TIENE UNA DISTRIBUCION NORMAL, COMPOTAMIENTO DE CAMPANA(GAUS), MEDIA CONCENTRADA EN 1.7.
# Out:
# <Axes: >

# %% [markdown]
# **Establecemos las hipótesis**

# %% [markdown]
# $H_0$:  La muestra de la altura de los jefes del hogar proviene de una distribución normal.
#
# $H_1$: La muestra de la altura de los jefes del hogar no proviene de una distribución normal.

# %%
# 8°)

normaltest(datos.Altura)
# Out:
# NormaltestResult(statistic=0.19973093957002253, pvalue=0.9049591541967501)

# %%
# 9°) Seperamos los valores y los Imprimimos --->
stats_test, p_valor = normaltest(datos.Altura)
print(stats_test)
print(p_valor)
# Out:
# 0.19973093957002253
# 0.9049591541967501

# %% [markdown]
# <font color='red'> Rechazamos la Hipotesis $H_0$ si el $p$-valor $\leq \alpha$ </font>

# %%
# 10°) Comprobamos --->

p_valor <= significancia

# Nos devuelve FALSE, respuesta abajo -->
# Out:
# False

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} > \alpha$</font>, por lo tanto NO tenemos suficiente evidencia en la muestra para rechazar $H_0$.

# %% [markdown]
# <font color='blue'>**Conclusión:** Con un nivel de significancia del 5% concluimos que la muestra de la altura de los jefes del hogar proviene de una distribución normal.</font>

# %% [markdown]
# ## <font color=green>2.2 Pruebas de hipótesis para  parámetros </font>
#
# ***

# %% [markdown]
# ¿Los jefes del hogar tienen una **altura promedio** de 1,70 cm?
#
# **Observe que el parámetro de interés es la média $(\mu)$**

# %% [markdown]
# ### **Conceptos importantes**

# %% [markdown]
# > <b>Estadística de prueba</b>: Es una estadística o variable aleatoria que se deriva del estimador puntual del parámetro de interés. En ella se comparan la hipótesis postulada y los datos observados.
#
# > <b> Región Crítica </b>: Los valores de la estadística de prueba que conllevan al rechazo de $H_0$.

# %% [markdown]
# ### **Etapas básicas de una prueba**

# %% [markdown]
# **Paso 1: Establecer las hipótesis $H_0$ y $H_1$**;
#
#  <font color='red'>Puntos importantes</font>
# > 1. **La afirmación o declaración sobre el parámetro poblacional** $(\mu)$ y que en general es vinculada a un valor de referencia, o a una especificación estándar o histórica, debe ser formulada como **la hipótesis nula** $H_0$.
# > 2. De manera general, la afirmación sobre el parámetro poblacional $(\mu)$ que **sospechamos que es verdadera**, debe ser formulada como **hipótesis alterna** $H_1$.
# > 3. Se pueden plantear las siguientes pruebas de hipótesis:
#
# > - Prueba de hipótesis <font color='red'>bilateral</b></font>
# $$
# \begin{cases}
# H_0: \mu = \mu_0   \\
# H_1: \mu \neq  \mu_0
# \end{cases}
# $$
#
# >- Prueba de hipótesis <font color='red'>unilateral a derecha</font>
# $$
# \begin{cases}
# H_0: \mu \leq \mu_0   \\
# H_1: \mu > \mu_0
# \end{cases}
# $$
#
# > - Prueba de hipótesis <font color='red'>unilateral a izquierda</font>
# $$
# \begin{cases}
# H_0: \mu \geq \mu_0   \\
# H_1: \mu < \mu_0
# \end{cases}
# $$
#
# > 4. En una prueba de hipótesis bilateral, la región de no rechazo corresponde a un intervalo de confianza para el parámetro de interés.

# %% [markdown]
# **Paso 2: Fijar el nivel de significancia $(\alpha)$ de la prueba**
#
# <font color='red'>Puntos importantes</font>
# > 1. El nivel de significancia $(\alpha)$ es el tamaño de la región de rechazo.
# > 2. Los valores más frecuentes usados para $\alpha$ son $1\%$, $5\%$ y $10\%$
# > 3. El complemento de la región de rechazo $(1-\alpha)$ corresponde al nivel de confianza.

# %% [markdown]
# ![Nivel de Significancia](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Nivel_Significancia_mu.png)

# %% [markdown]
# **Paso 3: Determinar la distribución de muestreo y Estadística de Prueba adecuada**
#
# <font color='red'>Puntos importantes</font>
# > 1. Si la muestra aleatoria proviene de una **distribución normal con varianza conocida** $(\sigma^2)$, la estadística de prueba es
# $$ Z = \frac{\overline{X} - \mu_0}{\sigma/\sqrt{n}}  \sim N(0,1),$$
# siendo $\overline{X}$ la media muestra, $\mu_0$ un valor de referencia.
# > 2. Si la muestra aleatoria proviene de una **distribución normal con varianza desconocida** $(\sigma^2)$, la estadística de prueba es
# $$ T = \frac{\overline{X} - \mu_0}{S/\sqrt{n}}  \sim t(n-1),$$
# donde $n-1$ son los grados de libertad de la distribución t-Student.
# > 3. Si no sabemos de que distribución proviene la muestra, pero $n$ es suficientemente grande $(n\geq 30)$ podemos utilizar una de las estadística anteriores, conforme lo establece el teorema del límite central (TLC)
# > 4. Si no sabemos de que distribución proviene la muestra y $n$ es pequeño $(n<30)$ debemos aumentar el tamaño de la muestra o usar pruebas no paramétricas.

# %% [markdown]
# <font color ='red'> Resumen </font>

# %% [markdown]
# ![Resumen una media](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_mu.png)

# %% [markdown]
# **Paso 4: Determinar la Región crítica.**
#
# <font color='red'>Puntos importantes</font>
# > 1. La localización de la región crítica depende de la forma de la hipótesis alterna $(H_1)$.
# > 2. Si $H_1: \mu \neq \mu_0$, la región crítica se divide en las dos colas de la distribución de la estadística de prueba, o sea que una parte estará en la cola derecha y la otra en la cola izquierda.
# > 3. Si $H_1: \mu > \mu_0$, la región crítica se encuentra en la cola derecha de la distribución de la estadística de prueba.
# > 4.  Si $H_1: \mu < \mu_0$, la región crítica se encuentra en la cola izquierda de la distribución de la estadística de prueba.

# %% [markdown]
# ![Region Critica una media](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_mu.png)

# %% [markdown]
# **Paso 5: Tomar la Decisión y Concluir**
#
# <font color='red'>Puntos importantes</font>
#
# Podemos decidir si rechazamos o no $H_0$ usando dos criterios:
# > 1. Si la Estadística de prueba $(Z \, \textrm{o}\, T)$  cae en la región de rechazo, entonces rechazamos $H_0$.
# > 2. Si $p$-valor $\leq \alpha$ rechazamos $H_0$. El cálculo del $p$-valor está ligado al tipo de hipótesis.  Asumiendo que $W$ es una estadística de prueba ($Z$ o $T$) cualquiera, tenemos que
# >- Prueba <font color='red'>bilateral $(H_1: \mu \neq \mu_0)$</font>
#
# $$p-\textrm{valor}= 2\times P(W \geq Z) = 2\times [1-P(W < Z) ] $$.
#
# >- Prueba <font color='red'>Unilateral a derecha $(H_1: \mu > \mu_0)$</font>
#
# $$p-\textrm{valor}= P(W \geq Z)= 1-P(W < Z)$$
#
# >- Prueba <font color='red'>Unilateral a izquierda $(H_1: \mu < \mu_0)$</font>
#
# $$p-\textrm{valor}= P(W \leq Z)$$.

# %% [markdown]
# # <font color=green>3. PRUEBA DE HIPÓTESIS PARA UNA MEDIA </font>
# ***

# %% [markdown]
# ## <font color=green>3.1 Prueba Bilateral</font>
# ***

# %% [markdown]
# ### **Problema**

# %% [markdown]
# Una máquina que llena **paquetes de café** estaba regulada para llenarlos con un **peso medio de $500 \,g$**.  Después de un tiempo de uso, la máquina se ha desregulado y se desea saber cuál es el **peso medio actual** $\mu$ con el que la máquina llena los paquetes de café. Cuando el volumen medio cae debajo de $500 \,g$ la empresa se preocupa en perder ventas y tener problemas con los organos fiscalizadores. Por otro lado, cuando el valumen pasa los $500 \,g$ la empresa empieza a preocuparse con pérdidas en el proceso de producción.
#
# El sector de control de calidad de la empresa, extrae periodicamente **muestras de 50 paquetes** para monitorear el proceso de producción. Para cada muestra, realiza una **prueba de hipótesis** para evaluar si la máquina se desajustó. En todos los casos, el equipo de control de calidad asumió un **nivel de significancia del 5%**.
#
# Suponga que una muestra **muestra de 50 paquetes** tuvo un peso promedio de $503.24 \, g$. ¿Es este valor medio muestral suficientemente mayor que $500 \, g$ para hacernos rechazar la hipótesis de que el promedio del proceso es $500 \, g$ al **nivel de significancia del 5%**?
#
# Asuma que el peso de los paquetes que llena la máquina se distribuye normalmente con una desviacion estándar de $4.5 \, g$.

# %% [markdown]
# Si denotamos por \\
# <font color='blue'>$\mu$</font> $\Rightarrow$ el peso medio de los paquetes de cafe. \\
# <font color='red'>$\mu_0$</font> $\Rightarrow$ el peso medio de referencia. \\
#
# las hipótesis que queremos probar son \\
# $
# \begin{cases}
# H_0: \mu = 500\\
# H_1: \mu \neq 500
# \end{cases}
# $
#
# observe que <font color='red'>$\mu_0 = 500$.</font>
#
# ***

# %% [markdown]
# **Datos del problema**

# %%
# 1°) La profesora ya nos da los 5o paquetes con valores inventados del peso para cada paquete y
# y los coloco en una Lista ---->

muestra_Cafe = [509, 505, 495, 510, 496, 509, 497, 502, 503, 505,
                501, 505, 510, 505, 504, 497, 506, 506, 508, 505,
                497, 504, 500, 498, 506, 496, 508, 497, 503, 501,
                503, 506, 499, 498, 509, 507, 503, 499, 509, 495,
                502, 505, 504, 509, 508, 501, 505, 497, 508, 507]

# %%
# 2°) Importamos biblioteca Pandas y creamos DATAFRAME con esos datos para trabajar con ellos --->
import pandas as pd

# %%
muestra_Cafe = pd.DataFrame(muestra_Cafe, columns = ["muestra_Cafe"])
muestra_Cafe.head()
# Out:
#    muestra_Cafe
# 0           509
# 1           505
# 2           495
# 3           510
# 4           496

# %%
# 3°) Datos que nos da el problema --->

desviacion = 4.5 # Desviacion poblacional
mu_0 = 500
n = 50
media_muestral = 503.24 # La media del peso de cada uno de los 50 paquetes.
significancia = 0.05 # Alpha
confianza = 1 - significancia # Confianza=95%, Significancia=0.05

# %% [markdown]
# #### <b> Haciendo cálculos </b>
#
# Para probar la Hipotesis, seguimos las ETAPAS.

# %% [markdown]
# <font color='orange'>**Paso 1: Establecer las hipótesis $H_0$ y $H_1$**
#
# $\mu\Rightarrow$ el peso medio de los paquetes de cafe.
#
#
# $
# \begin{cases}
# H_0: \mu = 500   \\
# H_1: \mu \neq 500
# \end{cases}
# $
#
# En este caso tenemos que $\mu_0 = 500 $

# %% [markdown]
# **<font color='orange'>Paso 2: Fijar el nivel de significancia $\alpha$ de la prueba**
#
# $\alpha = 0.05$  ---> Es una Pueba Bilateral, por lo tanto tenemos 2 colas de 0.025 = 0.05 alpha.

# %% [markdown]
# **<font color='orange'>Paso 3: Determinar la distribución de muestreo y Estadística de Prueba adecuada**

# %% [markdown]
# ![Resumen una media](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_mu.png)

# %% [markdown]
# Podemos afirmar que es una Distribucion Normal porque el enunciado del probema lo dice: Asuma que el peso de los paquetes que llena la máquina se distribuye normalmente con una desviacion estándar de $4.5 \, g$.
#
# Como la muestra es normal y $\sigma$ es conocido(4.5), **la estadística de prueba adecuada** es
# $$Z=\frac{\overline{X} - \mu_0}{\sigma/\sqrt{n}}$$
#
# Sabemos  que $Z$ se distribuye aproximadamente como una normal estándar.

# %%
# 4°) Importamos NUMPY, porque tenemos que calcular la raiz de la formula --->
import numpy as pd

# %%
z = (media_muestral - mu_0) / (desviacion / np.sqrt(n))
    # X=503.24      - 500       o=4.5     / raiz(n)= 50
z
# NOS DEVUELVE EL VALOR ESTADISTICO DE PRUEBA ES DE 5.09
# Out:
# 5.091168824543157

# %% [markdown]
# **<font color='orange'>Paso 4: Determinar la región crítica**

# %% [markdown]
# ![Region Critica Bilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Bilateral.png)

# %% [markdown]
# - Debemos determinar los valores -$z_{\alpha/2}$ y $z_{\alpha/2}$, que son los que nos permiten decidir si rechazamos la Hipotesis Nula.

# %% [markdown]
# - **Obteniendo $z_{\alpha/2}$**, sabemos que la ACUMULADA es de 0.025 + 0.95 hasta llegar a $z_{\alpha/2}$ que nos da 0.975. Para calcular esto usamos la Funcion NORM de SCIPY.
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
# 5°) Importamos SCIPY con la funcion NORM --->
from scipy.stats import norm

# %%
z_alpha_2 = norm.ppf(0.975)
z_alpha_2

# NOS DEVUELVE EL VALOR DE  ZALPHA/2
# Out:
# 1.959963984540054

# %% [markdown]
# <font color='orange'>**Por lo tanto, la Región Crítica es como sigue**

# %% [markdown]
# ![Valor Critico Bilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Bilateral.png)

# %% [markdown]
# **<font color='orange'>Paso 5: Tomar la decisión y concluir**
#
# <font color='red'>¿$Z = 5,09$ está en la Región Crítica?</font> o equivalentemente <font color='red'>¿ $Z \leq -1,96$ ou $Z \geq 1,96$?</font>

# %%
z >= z_alpha_2
# NOS DE VUELVE TRUE, ES DECIR SI, PORQUE 5.09 ES MAYOR A 1.96

# RTA = SE RECHAZA LA HIPOTESIS NULA, ES DECIR, LA MAQUINA NO ESTA REGULADA, LA MAQUINA ESTA COLOCANDO MAS
# CAFE O MENOS CAFE EN MEDIA(PROMEDIO), ES DECIR M =DISTINTO A 500
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$Z \geq 1,96$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# ![Decision Cafe](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Cafe.png)

# %%
# EJEMPLO AULA --->

# Un fabricante de harina afirma que la cantidad promedio de harina en el empaque de su producto principal es de 500 g.
# Una prueba de pesaje en 30 paquetes muestreados al azar mostró un peso promedio igual a 501 g. Estudios previos afirman
# que la distribución del peso sigue una NORMAL con una desviación estándar de 20 g. Considerando un nivel de significancia del 5%,
#responda las siguientes preguntas.

# 1) ¿Cuál es la hipótesis nula que se va a probar?
# 2) ¿Cuál es el valor de la estadística de prueba?
# 3) ¿Cuál es la conclusión de la prueba?

desviacion_estand = 20 # Desviacion poblacional
mu_0 = 500
n_ = 30
media_muest = 501 # La media del peso de cada uno de los 30 paquetes.
signific = 0.05 # Alpha
confian = 1 - signific # Confianza=95%, Significancia=0.05

# 2) ¿Cuál es el valor de la estadística de prueba?---->

# Como la muestra es normal y O es conocido(20), la estadística de prueba adecuada es:
z_ = (media_muest - mu_0) / (desviacion_estand / np.sqrt(n))
    # X=501      - 500       o=20            / raiz(n)= 30
z_
# RTA = NOS DEVUELVE EL VALOR ESTADISTICO DE PRUEBA ES DE = 0.27386127875258304
# Out:
# 0.3535533905932738

# %%
z_alp_2 = norm.ppf(0.975)
z_alp_2

# RTA = NOS DEVUELVE EL VALOR DE  ZALPHA/2 = 1.95(1.959963984540054)
# Out:
# 1.959963984540054

# %%
# 1) ¿Cuál es la hipótesis nula que se va a probar? ---->
# 3) ¿Cuál es la conclusión de la prueba? ---->
z >= z_alp_2

# NOS DE VUELVE FALSE, ES DECIR NO, PORQUE ES 0.27

# RTA = NO SE RECHAZA LA HIPOTESIS NULA, ES DECIR, PORQUE 0.27 NO ESTA DENTRO DE LOS PUNTOS
# CRITICOS DEL AREA DE RECHAZO DE LA CURVA, SINO DENTRO DEL AREA DE NO RECHAZO DE LA HIPOTESIS HO POR DEBAJO DE LA CURVA!!
# Out:
# True

# %% [markdown]
# ###<font color='orange'>CRITERIO DEL P-VALOR
#
# <font color='red'>Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# Recordemos que cuando la prueba es bilateral $(H_1: \mu \neq 500)$ el $p$-valor se calcula como
#
# $$p-\textrm{valor}= 2\times P(W \geq Z) = 2\times [1-P(W < Z)]$$.
#
# W, estadistica de prueba(5.09)

# %%
# 1°) Ahora tomamos la desicion con el CRITERIO de P-VALOR, que es el menor nivel de SIGNIFICANCIA, con el que
# rechazamos la Hipotesis Nula, es un valor extremo a la estadistica de prueba que calculamos(5.09) y nos da un
# area mas pequeña --->

# 2 x P(W >= z):
p_valor = 2*(norm.sf(z))
p_valor
# Out:
# 3.558629930076567e-07

# %%
# 2 x [1 - P(W < Z)]:
p_valor = 2*(1 - norm.cdf(z))
p_valor

# NOS DEVUELVE CASI EL MISMO P-VALOR, USANDO CUALQUIERA DE LAS 2 PARTES DE LA FORMULA.
# (p−valor=2×P(W≥Z)=2×[1−P(W<Z)])
# Out:
# 3.5586299307333036e-07

# %%
# 2°) Decidimos se rechazamos la Hipotesis Nula, comprando el p−valor ≤ α, donde alpha 0.05 --->

p_valor <= significancia

# NOS DICE QUE SI!
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Se sechaza la hipótesis nula $H_0$ de que la máquina llena los paquetes de café con un peso promedio de $500\, g$. Entonces, deben tomarse medidas para ajustar la máquina.</font>

# %% [markdown]
# ### <font color='orange'><b>Usando biblioteca de Phyton </b>
#
# Nos presentan 2 METODOS para hacer todo mucho mas rapido --->

# %% [markdown]
# ### <font color='red'> - Usando ztest</font>

# %% [markdown]
# https://www.statsmodels.org/stable/generated/statsmodels.stats.weightstats.ztest.html

# %%
# 1°) Importamos la biblioteca --->

from statsmodels.stats.weightstats import ztest

# %%
# 2°) Usamos la funcion ZTETS y colocamos los argumentos dentro del Parametro()--->

ztest(x1 = muestra_Cafe, value = mu_0, alternative = "two-sided")
        # DataFrame            # 500   Hipotesis Altura = 2 colas,Bilateral.

# NOS DEVUELVE LOS VALORES DE ESTADISTICA DE PRUEBA(5.10955978) Y P_VALOR(5.10955978) EN UN ARRAY.
# Out:
# (array([5.10955978]), array([3.22910317e-07]))

# %%
# 3°) Ordenamos valores para que se vean mejor --->
z, p_valor = ztest(x1 = muestra_Cafe, value = mu_0, alternative = "two-sided")
print(z[0]) # porque es un arreglo
print(p_valor[0])
# Out:
# 5.109559775991873
# 3.229103172445771e-07

# %%
# 4°) Ahora con el CRITERIO de P_VALOR debemos comparar ese valor con el nivel de SIGNIFICANCIA --->

p_valor[0] <= significancia
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# ###<font color='red'>- Usando DescrStatsW</font>

# %% [markdown]
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.DescrStatsW.html

# %%
# 1°) Importamos la biblioteca --->
from statsmodels.stats.weightstats import DescrStatsW

# %%
# 2°) Lo primero que tenemos que hacer para usar esta funcion es crear un OBJETO del tipo de la esa Funcion --->

test = DescrStatsW(muestra_Cafe)
#Objeto           #Le pasamos la muestra

# %%
# 3°) Ahora realizamos la prueba --->

test.ztest_mean(value = mu_0, alternative = "two-sided")

# NOS DEVUELVE LOS VALORES DE ESTADISTICA DE PRUEBA(5.10955978) Y P_VALOR(5.10955978) EN UN ARRAY.
# Out:
# (array([5.10955978]), array([3.22910317e-07]))

# %%
# 4°) Lo separamos para que se vean mejor --->

z, p_valor = test.ztest_mean(value = mu_0, alternative="two-sided")
print(z[0]) # porque es un arreglo
print(p_valor[0])
# Out:
# 5.109559775991874
# 3.2291031724457596e-07

# %%
# 5°) El P-VALOR lo comparamos con α (alpha), SIGNIFICANCIA, para decidir si rechazamos la Hipotesis Nula -->

p_valor[0] <= significancia

# MISMA CONCLUCION QUE CON LA FORMULA DE ZTEST.
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Se sechaza la hipótesis nula $H_0$ de que la máquina llena los paquetes de café con un peso promedio de $500\, g$. Entonces, deben tomarse medidas para ajustar la máquina.</font>

# %% [markdown]
# ### **Resumiendo**

# %% [markdown]
# ![Bilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Bilateral.png)

# %%
# EJERCICIO AULA --->

# Considere nuevamente los datos del ejercicio anterior. Un fabricante de harina afirma que la cantidad promedio de harina en los empaques
# de su producto principal es de 500 g. Una prueba de pesaje en 30 paquetes muestreados al azar mostró un peso promedio igual a 501 g.
# Estudios previos afirman que la distribución del peso sigue una normal y que la desviación estándar de la población es igual a 20 g.
# Con un nivel de significancia del 5%, pruebe la hipótesis nula de que el promedio del proceso es igual a 500 g y
# marque la alternativa que indica el p-valor de la prueba aplicada (considere solo 3 lugares decimales).

#p_valor = 2*(1 - norm.cdf (Z))
# e
#p_valor = 2*(norm.sf (Z))

# RTA = 0,784 revisar!!!

# %% [markdown]
# ## <font color=green>3.2 Prueba Unilateral</font>

# %% [markdown]
# ### **Problema**

# %% [markdown]
# Una cadena de comidas rápidas que se dedica a vender únicamente snacks típicos de Colombia, **afirma que el tiempo medio para servir uno de esos snacks es de aproximadamente 12 minutos**. Una empresa que investiga casos de publicidad engañosa **sospecha que ese tiempo es mayor**. Con el fin de probar la afirmación de la cadena, la empresa selecciona aleatoriamente **una muestra de 100 snacks** en varios establecimientos de esta cadena y que serven este tipo de productos, y mide el tiempo que demoran en servir cada uno.
# **Asumiendo que esa población se distribuye aproximadamente como una normal** y considerando un **nivel de significancia del 5%** ¿qué se puede concluir sobre la declaración de la cadena?

# %% [markdown]
# Si denotamos por \\
# <font color='blue'>$\mu$</font> $\Rightarrow$ el tiempo medio en servir uno snacks. \\
# <font color='red'>$\mu_0$</font> $\Rightarrow$ el tiempo medio de referencia. \\
#
# las hipótesis que queremos probar son \\
#
# $
# \begin{cases}
# H_0: \mu = 12\\
# H_1: \mu > 12
# \end{cases}
# $
#
# observe que  <font color='red'>$\mu_0 = 12$.</font>, es > 12 porque la empresa que investiga, sospecha que servir el snacks lleva mas de 12 minutos.
#
# ***

# %% [markdown]
# **Datos del problema**
#
#   Parametro de Interes es el tiempo Medio de servir snacks.

# %%
# 1°) La profesora nos da los valores de ma muestra aleatoria de los 100 --->
# El primer snacks que tomo la empresa demoro 21.99, el segundo 22.83, y asi sucesiavamente

muestra_snacks = [21.99, 22.83, 12.82, 17.57, 13.22, 16.88, 12.52,  7.51, 12.03, 13.63,
                  15.82, 17.27, 11.04,  5.47, 17.55, 21.21, 13.40, 10.83, 12.24, 16.67,
                  10.81, 17.33, 11.10,  4.40,  6.22, 10.48, 16.96,  2.77, 19.80, 14.79,
                  15.64, 16.90, 14.89, 12.88, 15.80, 11.10,  6.81, 18.45, 20.11, 16.07,
                  14.90, 15.43, 19.16,  9.92, 20.56, 18.50, 13.32, 14.11, 27.95, 12.10,
                  16.74,  8.76, 16.94, 14.83,  6.62, 13.47, 14.04,  5.12, 13.45,  9.80,
                  12.21, 16.95, 16.72, 11.95,  8.82,  4.15,  8.35, 15.13, 12.90, 11.93,
                  14.79, 19.91, 12.75,  5.97,  5.08, 19.19, 10.82,  9.66, 16.52, 16.80,
                  16.22, 19.81, 18.40, 20.73,  5.87,  9.83, 16.72, 16.44, 25.38, 23.08,
                  3.43,  17.90,  8.56,  9.48, 11.36, 17.08, 12.81, 15.03, 20.50, 12.22]

# %%
# 2°) Con esos datos creamos un DataFrame --->
import pandas as pd

muestra_snacks = pd.DataFrame(muestra_snacks, columns = ["muestra_snacks"])
muestra_snacks
# Out:
#     muestra_snacks
# 0            21.99
# 1            22.83
# 2            12.82
# 3            17.57
# 4            13.22
# ..             ...
# 95           17.08
# 96           12.81
# 97           15.03
# 98           20.50
# 99           12.22
#
# [100 rows x 1 columns]

# %%
# 3°) Datos que nos da el problema --->

mu_0 = 12
significancia = 0.05
confianza = 1 - significancia
n = 100

# %% [markdown]
# #### **Haciendo cálculos**

# %% [markdown]
# <font color='orange'>**Paso 1: Establecer las hipótesis $H_0$ y $H_1$**
#
# $\mu\Rightarrow$ el tiempo medio en servir uno snacks.
#
# $
# \begin{cases}
# H_0: \mu \leq 12   \\
# H_1: \mu > 12
# \end{cases}
# $
#
# En este caso tenemos:
# >- Una prueba unilateral a derecha
# >- El valor de referencia es  <font color='red'>$\mu_0 = 12 $</font>.

# %% [markdown]
# <font color='orange'>**Paso 2: Fijar el nivel de significancia $\alpha$ de la prueba**
#
# $\alpha = 0,05$

# %% [markdown]
# <font color='orange'>**Paso 3: Determinar la distribución de muestreo y Estadística de prueba adecuada**

# %% [markdown]
# ![Resumen una media](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_mu.png)

# %% [markdown]
# - Ver si la muestra proviene, segun el cuadro, de una Distribucion Normal, en el enunciado nos dice que asumamos una Distribucion Normal(SI)
# - Luego vemos si la Desviacion Estandar(o), sigma, es conocida?, pero el problema NO nos da ninguna informacion(NO), entonces:
#
# Como la muestra es normal y $\sigma$ es desconocido, **la estadística de prueba adecuada** es
#
# $$T=\frac{\overline{X} - \mu_0}{S/\sqrt{n}}$$
#
# <font color='yellow'>Sabemos que $T$ se distribuye $t$-Student con $n-1$ grados de libertad.

# %%
# 4°) Calculamos el T, pero antes tenemos que calcular la MEDIA MUESTRAL(X), que NO la tenemos y la necesitamos
# para aplicar la Formula ---->

media_muestral = muestra_snacks.mean()[0] # muestra_snacks, media de los datos - [0], porque es un arreglo
media_muestral
# Out:
# 13.9298

# %%
# Tambien debemos calcular antes la DESVIACION ESTANDAR(S), que NO la tenemos, esta desviacion muestral es a partir
# de la muestra y no de la muestra de la poblacion --->

desviacion_muestral = muestra_snacks.std()[0]
desviacion_muestral          # .std=desviacion estandar
# Out:
# 5.01503496669482

# %%
# Ahora calculamos T --->

T = (media_muestral - mu_0) / (desviacion_muestral / np.sqrt(n))
  # 13.9298=X         12       5.01503496669482=S    raiz(100)
T

# NOS DEVUELVE LA ESTADISTICA DE PRUEBA!
# Out:
# 3.8480290024215784

# %% [markdown]
# <font color='orange'>**Paso 4: Determinar la región crítica**
#
# Para concluir si rechazamos o no la Hipotesis Nula declarada en el paso 1.

# %% [markdown]
# ![Region Critica Snacks](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Snacks.png)

# %% [markdown]
# ###<font color='orange'>Obteniendo $t_\alpha$
#
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.t.html

# %%
# 5°) Para calcular t de Alpha importamos la funcion t de Scipy --->
from scipy.stats import t as t_student

# %%
# 6°) La Distribucion T_STUDENT envuelve los GRADOS DE LIBERTAD que es el tamaño total de la
# muestra - 1 (n - 1) ---->

grados_libertad = n - 1
              # n=100

# %%
# 7°) Calculamos el t de alpha --->

t_alpha = t_student.ppf(confianza, grados_libertad)
                 #ppf=porque esta a la derecha
t_alpha
# Out:
# 1.6603911559963895

# %% [markdown]
# Por lo tanto, la Región Crítica es como , ahora debemos comparar t alpha con T, si esta a la izquierda o a la derecha el valor.

# %% [markdown]
# ![Valor Critico Snacks](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Snacks.png)

# %% [markdown]
# <font color='orange'>**Paso 5: Tomar la decisión y concluir**
#
# <font color='red'>¿$T = 3,85$ está en la Región Crítica?</font> o equivalentemente <font color='red'> ¿ $T \geq 1,66$?</font>

# %%
# 8°)

T >= t_alpha

# NOS DEVUELVE SI, EL VELOR ESTA EN LA REGION CRITICA T ES MAYOR A 1.66. SE RECHAZA Ho
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$T \geq 1,66$</font> y por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# ![Decision Snacks](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Snacks.png)

# %%
# EJEMPLO AULA --->

# La empresa Limpia Residuos garantiza poder realizar el tratamiento de aguas residuales y obtener,como mínimo,
# 150 g de impurezas por cada mil litros de aguas residuales tratadas. Veinte muestras de mil litros de aguas residuales mostraron,
# en promedio, 153 g de impurezas y una desviación estándar igual a 90 g.

# Suponiendo que la muestra de las aguas residuales sigue una distribución normal y asumiendo un nivel de significancia del 5%
# ¿sería posible estar en desacuerdo con la empresa Limpia Residuos?

from scipy.stats import t as t_student
import numpy as np

med_muestr = 153
des_muestr = 90
mu_0_ = 150
signi = 0.05
conf = 1 - signi
n = 20

grados_de_lib = n - 1

T_ = (med_muestr - mu_0_) / (des_muestr / np.sqrt(n))

t_alph = t_student.ppf(signi, grados_de_lib)
print('t(alpha) =', round(t_alph, 4))
print('T =', round(T, 4))
if(T_ <= t_alph):
  print('Rechazar H0')
else:
  print('No rechazar H0')

 # No rechazar H0, es decir, la afirmación de la empresa es cierta.
# Out:
# t(alpha) = -1.7291
# T = 3.848
# No rechazar H0

# %% [markdown]
# ###<font color='orange'>CRITERIO DEL P-VALOR
#
# <font color='red'>Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# Recordemos que cuando la prueba es unilateral a derecha $(H_1: \mu > 12)$ el $p$-valor se calcula como
#
# $$p-\textrm{valor}= P(W \geq T) = 1-P(W < T)$$.

# %% [markdown]
#  o si $p-\textrm{valor}\leq \alpha$

# %%
# 1°) Calculamos el P-VALOR a mano --->

# P(W ≥ T):
p_valor = t_student.sf(T, grados_libertad)
p_valor
# Out:
# 0.00010549375091642149

# %%
# 2°) La otra parte de la formula, ya que es lo mismo calcularlo de una manera o la otra -->

# 1−P(W < T):
p_valor = 1 - t_student.cdf(T, grados_libertad)
p_valor
# Nos devuelven la 2 partes de la formula valores proximos.
# Out:
# 0.00010549375091639668

# %%
# 3°) Concluimos si rechazamos o NO la Hipotesis Nula(Ho), comparamos el P_VALOR con la SIGNIFICANCIA --->

p_valor <= significancia

# RECHAZAMOS LA HIPOTESIS NULA Ho, LA EMPRESA CONFIRMA LA SOSPECHA DE PROPAGANDA ENGAÑOSA.
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Se rechaza la hipótesis nula $H_0$ de que la cadena de comidas rápidas demora en promedio 12 minutos en servir un snacks. Entonces,  la empresa confirma sus sospechas de propaganda engañosa.</font>

# %% [markdown]
# #### <font color='orange'>Usando biblioteca de Phyton

# %% [markdown]
# <font color='red'>Usando DescrStatsW</font>
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.DescrStatsW.html

# %%
# 1°) Importamos la Funcion y biblioteca --->

from statsmodels.stats.weightstats import DescrStatsW

# %%
# 2°) Creamos OBJETO, y a este objeto le pasamos la funcion con Parametros --->

test = DescrStatsW(muestra_snacks)
# Objeto

# %%
# 3°) Hacemos la PRUEBA --->

test.ttest_mean(value = mu_0, alternative = "larger")
 # ttest = t_student                     # larger = porque es unilateral en este caso a la derecha

# NOS DEVUELVE T = 3.848029, P_VALUE = 0.00010549, GRADOS_LIBERTAD = 99.0
# Out:
# (array([3.848029]), array([0.00010549]), 99.0)

# %%
# 4°) Separamos los valores --->

t, p_valor, gl = test.ttest_mean(value = mu_0, alternative = "larger")
print(p_valor[0]) # Imprimos solo p_valor
# Out:
# 0.00010549375091642149

# %%
# 5°) Tomamos la Decision si se rechaza o NO la hipotesis Nula --->

p_valor[0] <= significancia

# TENEMOS SUFICIENTE EVIDENCIA PARA RECHAZAR Ho
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'> **Conclusión:** Se rechaza la hipótesis nula $H_0$ de que la cadena de comidas rápidas demora en promedio 12 minutos en servir un snacks. Entonces,  la empresa confirma sus sospechas de propaganda engañosa.</font>

# %% [markdown]
# <font color='orange'>EJERCICIO ADICIONAL --->
#
# **Suponiendo que la única información distribucional que tenemos es que la desviación estándar poblacional es 6 minutos ¿ se mantendrá la misma conclusión de que la cadena está haciendo propaganda engañosa?**

# %% [markdown]
# <font color='red'> Tenga en cuenta que</font>
# >- No podemos afirmar que la muestra proviene de una normal.
# >- La desviación estándar poblacional $\sigma$ es conocida ($\sigma = 6$).
# >- $n=100$ es grande.

# %% [markdown]
# ![Resumen una media](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_mu.png)
#
#
# - Se puede afirmar que la muestra proviene de una distribucion normal? NO, n >= 30 ?? SI, entonces utilizamos Z !!!

# %% [markdown]
# <font color='red'>Usando DescrStatsW</font>
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.DescrStatsW.html

# %%
# 1°) Usamos DescrStatsW y llamamos el objeto --->

test = DescrStatsW(muestra_snacks)

# %%
# 2°) Hacemos la Prueba pero sin Student, porque tenemos una distribucion Normal, usamos Z --->

t,p_valor = test.ztest_mean(value = mu_0,alternative = 'larger')
print(p_valor[0])
# Out:
# 5.953597980201217e-05

# %%
# 3°) Comparamos con ALPHA --->

p_valor[0] <= 0.05

# NOS DICE QUE ES VERDAD QUE EL P_VALOR ES MENOR QUE 0.05, ESTO SUCEDE CUANDO N ES GRANDE, LA DISTRIBUCION
# T_STUDENT QUEDA MUY PROXIMA A LA DISTRIBUCION NORMAL.
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='red'>Note que los resultados son cercanos y que las conclusiones son las mismas. Esto sucede cuando $n$ es grande, pues la distribución $t$-Student queda muy próxima a la distribución normal</font>.

# %%
# EJERCICIO AULA --->

# La pizzería Quesillo afirma que la cantidad de queso en sus pizzas familiares es de al menos 350 g con una desviación de 80 g.
# Una muestra de 35 pizzas de tamaño familiar reveló un promedio de 330 g de queso por pizza.
# Suponiendo un nivel de significancia del 5% ¿sería posible estar en desacuerdo con la afirmación de la pizzería?

from scipy.stats import norm
import numpy as np

media_muestral = 330
desviacion= 80
mu_0 = 350
significancia = 0.05
n = 35

Z = (media_muestral - mu_0) / (desviacion / np.sqrt(n))

z_alpha = norm.ppf(significancia)

print('z(alpha) =', round(z_alpha, 3))
print('Z=', round(Z, 3))

if(T <= z_alpha):
  print('Rechazar H0')
else:print('No rechazar H0')

#¡Correcto! A un nivel de significancia del 5% concluimos que no hay suficiente evidencia
# en la muestra para rechazar la hipótesis nula de que las pizzas familiares de Quesillo tienen al menos 350 g de queso.
# Out:
# z(alpha) = -1.645
# Z= -1.479
# No rechazar H0

# %% [markdown]
# ##<font color='orange'> **Resumiendo**

# %% [markdown]
# ![Unilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Unilateral.png)

# %% [markdown]
# # <font color=green>4. PRUEBA DE HIPÓTESIS PARA DIFERENCIA DE MEDIAS</font>
#
#
# ***

# %% [markdown]
# **Problema**
#
# En nuestro conjunto de datos de la **Encuesta Nacional por Muestra de Hogares - 2015** tenemos los salarios de los jefes de hogar. Un problema bastante conocido en Brasil es la **desigualdad de salarios entre hombres y mujeres**.
#
# Con el objetivo de probar esta desigualdad, seleccione dos muestras aleatorias de los jefes del hogar, una con **500 hombres** y otra con **500 mujeres**. **Pruebe la igualdad de las medias de los salarios de los dos géneros utilizando un nivel de significancia del 1% y asuma que las desviaciones estándar son iguales.**

# %% [markdown]
# Si denotamos por \\
#
# <font color='red'>$\mu_H$</font> $\Rightarrow$ el salario medio poblacional de jefes del hogar <font color='red'>hombres</font>,
#
# <font color='blue'>$\mu_M$</font> $\Rightarrow$  el salario medio poblacional de jefes del hogar <font color='blue'>mujeres</font>,
#
# podemos plantear las hipótesis como sigue
#
# $
# \begin{cases}
# H_0: \mu_H \leq \mu_M \,  \\
# H_1: \mu_H > \mu_M
# \end{cases}
# $
# **O equivalentemente**
# $
# \begin{cases}
# H_0: \mu_H - \mu_M \leq 0\,  \\
# H_1: \mu_H - \mu_M > 0
# \end{cases}
# $
#
# - Prueba Unilateral a derecha, porque en la Hipotesis alterna, que es en la que colocamos la sospecha de que los Hombres ganan mas que las Mujeres, el signo esta H_1:$
# \begin{cases} \mu_H > \mu_M \end{cases}
# $
# ***

# %% [markdown]
# **Selecionando las muestras**

# %%
# 1°) Seleccionamos las Muestras de los Hombres Y Mujeres, colocamos random_state = 101 para que los resultados
# sean los mismos que los presentados por la profesora --->

muestras_hombres = datos.query("Sexo == 0").sample(n = 500, random_state = 101).Renta
                                          #muestra

# %%
muestras_mujeres = datos.query("Sexo == 1").sample(n = 500, random_state = 101).Renta
                                          #muestra

# %% [markdown]
# **Datos del problema**

# %%
# 2°) Agregamos los datos del problema -->

significancia = 0.01
confianza = 1 - significancia
n_H = 500
n_M = 500

# %% [markdown]
# ## **Haciendo cálculos**

# %% [markdown]
# <font color='orange'>**Paso 1: Establecer las hipótesis $H_0$ y $H_1$**

# %% [markdown]
# Si denotamos por \\
#
# <font color='red'>$\mu_H$</font> $\Rightarrow$ el salario medio poblacional de jefes del hogar <font color='red'>hombres</font>,
#
# <font color='blue'>$\mu_M$</font> $\Rightarrow$  el salario medio poblacional de jefes del hogar <font color='blue'>mujeres</font>,
#
# podemos plantear las hipótesis como sigue
#
# $
# \begin{cases}
# H_0: \mu_H \leq \mu_M \,  \\
# H_1: \mu_H > \mu_M
# \end{cases}
# $
# **O equivalentemente**
# $
# \begin{cases}
# H_0: \mu_H - \mu_M \leq 0\,  \\
# H_1: \mu_H - \mu_M > 0
# \end{cases}
# $
#
# Observe que en este caso tenemos una hipótesis <font color='green'> Unilateral a Derecha</font>.

# %% [markdown]
# <font color='orange'>**Paso 2: Fijar el nivel de significancia $\alpha$ de la prueba**

# %% [markdown]
# $\alpha = 0,01$

# %% [markdown]
# <font color='orange'>**Paso 3: Determinar la distribución de muestreo y Estadística de prueba adecuada**

# %% [markdown]
# ![Resumen dos medias](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_Dif.png)

# %% [markdown]
# <font color='yellow'>¿Es posible afirmar que las muestras provienen de una distribución normal?
#
# >*Respuesta*: No.
#
#  <font color='yellow'>¿El tamaño de las muestras es grande? n >= 30?
# > *Respuesta*: Sí $(n_H = n_M = 500)$.
#
# <font color='yellow'>Conforme las respuestas anteriores, la **estadística de prueba adecuada** es
# $$Z = \frac{\left(\overline{X}_H - \overline{Y}_M\right) - D_0}{\sqrt{\frac{S^{2}_H}{n_H}+\frac{S^{2}_M}{n_M}}} \sim N(0,1)$$
#
# siendo:
# >- $\overline{X}_H$: el salario medio muestral de los jefes del hogar que son hombres,
#
# >- $\overline{Y}_M$: el salario medio muestral de los jefes del hogar que son mujeres,
#
# >- $S^{2}_H$: la varianza muestral del salario de los jefes del hogar que son hombres,
#
# >- $S^{2}_M$: la varianza muestral del salario de los jefes del hogar que son mujeres,
#
# >- $n_H$: Total de observaciones en la muestra de los salarios de los jefes del hogar que son hombres,
#
# >- $n_M$: Total de observaciones en la muestra de los salarios de los jefes del hogar que son mujeres,
#
# >- $D_0$: el valor de referecia de la diferencia entre $\mu_H$ y $\mu_M$.

# %%
# 3°) Calculamos la MEDIA MUESTRAL para HOMBRES Y MUJERES --->

media_muestral_H = muestras_hombres.mean()
media_muestral_H
# Out:
# 2142.608

# %%
media_muestral_M = muestras_mujeres.mean()
media_muestral_M
# Out:
# 1357.528

# %%
# 4°) Calculamos la VARIANZA para HOMBRES y MUJERES --->

varianza_muestral_H = muestras_hombres.var()
varianza_muestral_H
# Out:
# 6492562.892120241

# %%
varianza_muestral_M = muestras_mujeres.var()
varianza_muestral_M
# Out:
# 2464589.7487134263

# %%
# 5°) Diferencia --->

D_0 = 0

# %% [markdown]
# $$Z = \frac{\left(\overline{X}_H - \overline{Y}_M\right) - D_0}{\sqrt{\frac{S^{2}_H}{n_H}+\frac{S^{2}_M}{n_M}}} $$

# %%
# 6°) Calculamos la ESTADISTICA DE PRUEBA, con la Formula, para que sea mas facil separamos la Formula
# en NUMERADOR y DENOMINADOR --->

numerador = (media_muestral_H - media_muestral_M) - D_0
              # Xh           -   Ym                  0

# %%
denominador = np.sqrt(varianza_muestral_H/n_H + varianza_muestral_M/n_M)
           # RAIZ       S2H               500        S2M            500

# %%
# Calculamos Z --->
Z = numerador/denominador
Z
# NOS DEVUELEVE EL VALOR DE LA ESTADISTICA DE PRUEBA
# Out:
# 5.865620057764754

# %% [markdown]
# <font color='orange'>**Paso 4: Determinar la región crítica**

# %% [markdown]
# ![Region Critica Renta](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Renta.png)

# %% [markdown]
# <font color='orange'>Obteniendo $z_\alpha$

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
# 7°) Utilizamos Funcion NORM de Scipy para cacular el VALOR CRITICO, importamos biblioteca y Funcion -->
from scipy.stats import norm

# %%
# Calculamoc ALPHA --->

z_alpha = norm.ppf(0.99)
z_alpha
# Out:
# 2.3263478740408408

# %% [markdown]
# <font color='orange'>Por lo tanto la Región Crítica es

# %% [markdown]
# ![Valor Crítico Renta](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Renta.png)

# %% [markdown]
# <font color='orange'>**Paso 5: Tomar la decisión y concluir**
#
# <font color='red'>¿$Z = 5,87 $ está en la Región Crítica?</font> o equivalentemente <font color='red'> ¿ $Z \geq 2,33$?</font>

# %%
# 8°) Vemos si Z(estadistica de prueba) es mayos o igual a 2.33 -->

Z >= z_alpha

# RECHAZAMOS LA HIPOTESIS Ho,YA QUE EL VALOR SE ENCUENTRA EN EL AREA DE RECHAZO(DERECHA)
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$Z \geq 2,33$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# ![Decision Renta](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Renta.png)

# %%
# EJERCICIO AULA ---> Probando una nueva línea de shampoos:

# Un fabricante de cosméticos dice al agregar un nuevo compuesto químico a su línea de champús se puede promover el crecimiento del cabello
# en más de 2 centímetros en un período de 60 días. Para verificar si esto es cierto o no, se seleccionaron dos muestras de personas,
# en una se experimentó el nuevo shampoo (con el compuesto) y en la otra el shampoo antiguo (sin el compuesto). El largo del cabello
# de las personas fue medido antes y después del periodo de uso del shampoo asignado. Los valores de la tabla de abajo corresponden
# a la diferencia (en centímetros) entre largo del cabello antes y después, o sea el crecimiento del cabello.

#Shampoo Nuevo	Shampoo Antiguo
#    3,4	           0,3
#    4,9	           1,2
#    2,8	           1,2
#    5,5	           1,7
#    3,7	           1,1
#    2,5	           0,6
#    4,3	           1,2
#    4,6	           1,5
#    3,7	           0,5
#    3,4	           0,7

# Asumiendo un nivel de confianza del 95% y considerando que las poblaciones se distribuyen normalmente con varianzas iguales
# ¿podemos creer la afirmación del fabricante del shampoo?

# Ayuda: como este es un problema ligeramente diferente al presentado en nuestra clase, le indicaremos las hipótesis del problema:
# H_0: mu_N - mu_A <= 2
# H_1: mu_N - mu_A < 2

# Donde mu_N es el crecimiento medio del cabello con el uso del nuevo shampoo Y mu_A es el crecimiento medio del cabello con el uso del shampoo antiguo.

from scipy.stats import t as t_student
import numpy as np
import pandas as pd

shampoo_Nuevo = pd.Series([3.4, 4.9, 2.8, 5.5, 3.7, 2.5, 4.3, 4.6, 3.7, 3.4])
shampoo_Antiguo = pd.Series([0.3, 1.2, 1.2, 1.7, 1.1, 0.6, 1.2, 1.5, 0.5, 0.7])

significancia = 0.05
confianza = 1 - significancia
n_N = len(shampoo_Nuevo)
n_A = len(shampoo_Antiguo)
D_0 = 2

media_N = shampoo_Nuevo.mean()
media_A = shampoo_Antiguo.mean()

varianza_N = shampoo_Nuevo.var()
varianza_A = shampoo_Antiguo.var()

grados_de_libertad = n_N + n_A - 2 # t_STUDENT

numerador = (media_N - media_A) - D_0
S_p = ((n_N-1)*varianza_N + (n_A -1)*varianza_A)/grados_de_libertad
denominador = S_p*np.sqrt(1/n_N + 1/n_A)

T = numerador / denominador
T

t_alpha = t_student.ppf(significancia, grados_de_libertad)
t_alpha

# La estadística de prueba es la adecuada, pues la muestra proviene de una normal y sus varianzas son desconocidas pero iguales.

# T = 3,6083, No rechazar H_0, es decir, la afirmación del fabricante es cierta.
# Out:
# -1.734063606617536

# %% [markdown]
# ###<font color='orange'>CRITERIO DEL P-VALOR
#
# <font color='red'>Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# Recordemos que cuando la prueba es unilateral a derecha $(H_1: \mu_{H} - \mu_{y} > 0)$ el $p$-valor se calcula como
#
# $$p-\textrm{valor}= P(W \geq Z) = 1-P(W < Z)$$.

# %%
# 9°) En la parte anterior concluimos que los hombres ganas mas que las mujeres, confirmamos la sospecha, con base en la
# REGION CRITICA, ahora vamos a concluir con el P-VALOR --->
# Tomamos 1 − P(W < Z), es lo mismo con cualquiera de las 2 partes:

p_valor = 1 - norm.cdf(Z)
p_valor
# Out:
# 2.237286800266247e-09

# %%
p_valor <= significancia

# El P_VALOR <= ALPHA, por lo tanto rechazamos Ho
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Tenemos suficiente envidencia muestral para rechazar $H_0$, por lo tanto
# se concluye que el ingreso promedio de los hombres jefes de hogar es superior al ingreso promedio de las mujeres jefas de hogar. Esto confirma la alegación de desigualdad de ingresos entre géneros.</font>

# %% [markdown]
# ###<font color='orange'> Usando biblioteca de Phyton

# %% [markdown]
# <font color='red'>Usando DescrStatsW</font> (Prueba de Hipotesis para diferencia de medias en Python)
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.DescrStatsW.html

# %%
# 1°) Importamis biblioteca y funciones, con una funcion nueva mas que es CompareMeans() --->
from statsmodels.stats.weightstats import DescrStatsW, CompareMeans

# %%
# 2°) Creamos 2 OBJETOS, porque tenemos 2 Muestras --->

test_H = DescrStatsW(muestras_hombres)
test_M = DescrStatsW(muestras_mujeres)

# %%
# 3°) Creamos un OBJETO que va a ser la comparacion entre los 2 y utilizamos la funcion COMPARE --->

test_1 = test_H.get_compare(test_M) # Comparar test hombre con Compare, con test mujer

# %%
# 4°) Ahora aplicamos la PRUEBA --->

test_1.ztest_ind(value = D_0, alternative = "larger")
# Out:
# (5.850677325666713, 2.4478759705224908e-09)

# %%
# 5°) Separamos valores para mejor entendimiento --->

Z, p_valor = test_1.ztest_ind(value = D_0, alternative = "larger")
print(p_valor)
print(Z) # Nos devuelve aprox. mismos valores manual.
# Out:
# 2.4478759705224908e-09
# 5.850677325666713

# %%
# 6°) Comparamos el P_VALOR, con el valor de SIGNIFICANCIA --->

p_valor <= significancia

# Mismo valor que en forma manual.
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='red'>Usando CompareMeans</font> ( Mucho mas FACIL)
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.CompareMeans.ttest_ind.html

# %%
# 1°)
test_2 = CompareMeans(test_H, test_M) # Colocamos las Muestras

# %%
# 2°) Aplicamos la PRUEBA --->

Z, p_valor = test_2.ztest_ind(value = D_0, alternative = "larger")
print(p_valor)
print(Z)
# Out:
# 2.4478759705224908e-09
# 5.850677325666713

# %%
# 3°) Vemos si el P_VALOR es mayor o igual a la SIGNIFICANCIA --->

p_valor <= significancia

# MISMO RESULTADO QUE CON LA FORMA MANUAL Y CON LA FORMULA DESCRSTATSW!
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p-\textrm{valor} \leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# <font color='blue'>**Conclusión:** Tenemos suficiente envidencia muestral para rechazar $H_0$, por lo tanto
# se concluye que el ingreso promedio de los hombres jefes de hogar es superior al ingreso promedio de las mujeres jefas de hogar. Esto confirma la alegación de desigualdad de ingresos entre géneros.</font>

# %% [markdown]
# ##<font color='orange'>Generalizando

# %% [markdown]
# **En este tipo de prueba se comparan las medias de dos poblaciones independientes.**

# %% [markdown]
# Suponga que se tienen dos poblaciones independientes y que se extrae una muestra aleatoria de cada una, digamos $x$ y $y$, cuyas medias (poblacionales) son $\mu_x$ y $\mu_y$, y con varianzas (poblacionales) $\sigma^{2}_x$ y $\sigma^{2}_y$, respectivamente.
#
# Considere que el interés es probar hipótesis acerca de $\mu_x - \mu_y$, entonces se pueden plantear las siguientes pruebas de hipótesis:
#
# >1. Prueba de hipótesis <font color='red'>bilateral</b></font> $\hspace{2.2 cm}$
# $
# \begin{cases}
# H_0: \mu_x = \mu_y\\
# H_1: \mu_x \neq \mu_y
# \end{cases}
# $
# <font color='blue'>o equivalentemente </b></font>
# $
# \begin{cases}
# H_0: \mu_x - \mu_y = D_0\\
# H_1: \mu_x -  \mu_y \neq D_0
# \end{cases}
# $
#
# > 2. Prueba de hipótesis <font color='red'>unilateral a derecha</font> $\hspace{0.1 cm}$
# $
# \begin{cases}
# H_0: \mu_x \leq \mu_y\\
# H_1: \mu_x > \mu_y
# \end{cases}
# $
# <font color='blue'>o equivalentemente </b></font>
# $
# \begin{cases}
# H_0: \mu_x - \mu_y \leq D_0\\
# H_1: \mu_x -  \mu_y > D_0
# \end{cases}
# $
#
# >3. Prueba de hipótesis <font color='red'>unilateral a izquierda</font>
# $
# \begin{cases}
# H_0: \mu_x \geq \mu_y\\
# H_1: \mu_x < \mu_y
# \end{cases}
# $
# <font color='blue'>o equivalentemente </b></font>
# $
# \begin{cases}
# H_0: \mu_x - \mu_y \geq D_0\\
# H_1: \mu_x -  \mu_y < D_0
# \end{cases}
# $
#
# **$D_0$ es el valor de referencia de la diferencia entre las medias poblacionales.**

# %% [markdown]
# ###<font color='orange'> **Estadística de Prueba**

# %% [markdown]
# <font color='red'>Puntos importantes</font>
#
# > 1. Si ambas muestras aleatorias proviene de **distribuciones normales con varianzas conocidas** $(\sigma^2_{x}, \sigma^2_{y})$, la estadística de prueba es
#
# $$Z = \frac{\left(\overline{X} - \overline{Y}\right) - D_{0}}{\sqrt{\frac{\sigma^2_{x}}{n_{x}} + \frac{\sigma^2_{y}}{n_{y}}}} \sim N(0,1)$$
# en que $\overline{X}$ y $\overline{Y}$ son las medias muestrales.
#
# > 2. Si ambas muestras aleatorias proviene de **distribuciones normales con varianzas desconocidas** $(\sigma^2_{x}, \sigma^2_{y})$, la estadística de prueba dependerá de como sean $\sigma^2_{x}$ y $\sigma^2_{y}$:
#
# >- **Si** $\boldsymbol{\sigma^{2}_{x}=\sigma^{2}_{y}}$, la estadística de prueba es
# $$ T = \frac{\left(\overline{X} - \overline{Y}\right) - D_{0}}{S_{p}\sqrt{\frac{1}{n_{x}} + \frac{1}{n_{y}}}} \sim t_{(n_{x}+n_{y}-2)}; \hspace{0.9 cm} S_{p}=\frac{(n_{x}-1)S^{2}_{x} + (n_{y}-1)S^{2}_{y}}{n_{x}+n_{y}-2}$$
# donde $n_{x}+n_{y}-2$ son los grados de libertad de la distribución t-Student.
#
# >- **Si** $\boldsymbol{\sigma^{2}_{x}\neq \sigma^{2}_{y}}$, la estadística de prueba es
# $$ T = \frac{\left(\overline{X} - \overline{Y}\right) - D_{0}}{\sqrt{\frac{S^{2}_{x}}{n_{x}} + \frac{S^{2}_{y}}{n_{y}}}} \stackrel{aprox}{\sim} t_{v}; \hspace{0.9 cm} v= \frac{\left(\frac{S^2_{x}}{n_{x}}+\frac{S^{2}_{y}}{n_y}\right)^2}{ \frac{\left(S^2_{x}/n_{x}\right)^2}{n_{x}+2} + \frac{\left(S^2_{y}/n_{y}\right)^2}{n_{y}+1} } - 2  $$
#
# > 3. Si no sabemos la procedencia distribucional de las muestras, pero **$n$ es suficientemente grande $(n\geq 30)$**, la estadística de prueba adecuada es
# $$ Z = \frac{\left(\overline{X} - \overline{Y}\right) - D_{0}}{\sqrt{\frac{\sigma^2_{x}}{n_{x}} + \frac{\sigma^2_{y}}{n_{y}}}}  \sim N(0,1) $$
#
# > 4. Si no sabemos la procedencia distribucional de las muestras y **$n$ es pequeño $(n<30)$** debemos aumentar el tamaño de la muestra o usar pruebas no paramétricas.

# %% [markdown]
# ![Resumen dos medias](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Resumen_Dif.png)

# %% [markdown]
# ###<font color='orange'> **Región Critica**

# %% [markdown]
# ![Region Critica dos medias](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Dif.png)

# %% [markdown]
# ###<font color='orange'>**$p$-valor**

# %% [markdown]
# <font color='red'>Puntos importantes</font>
#
# Podemos decidir si rechazamos o no $H_0$ usando dos criterios:
# > 1. Si la Estadística de prueba $(Z \, \textrm{o}\, T)$  cae en la región de rechazo, entonces rechazamos $H_0$.
# > 2. Si $p$-valor $\leq \alpha$ rechazamos $H_0$. Asuma que $W$ es una estadística de prueba ($Z$ o $T$) cualquiera, entonces
# >- Prueba <font color='red'>bilateral $(H_1: \mu_{x} - \mu_{y} \neq D_0)$</font>
#
# $$p-\textrm{valor}= 2\times P(W \geq Z) = 2\times [1-P(W < Z) ] $$.
#
# >- Prueba <font color='red'>Unilateral a derecha $(H_1: \mu_{x} - \mu_{y} > D_0)$</font>
#
# $$p-\textrm{valor}= P(W \geq Z)= 1-P(W < Z)$$
#
# >- Prueba <font color='red'>Unilateral a izquierda $(H_1:\mu_{x} - \mu_{y} < D_0)$</font>
#
# $$p-\textrm{valor}= P(W \leq Z)$$.

# %% [markdown]
# # <font color=green>5. PRUEBAS CHI-CUADRADO</font>
# ***

# %% [markdown]
# ## **Tenemos dos tipos de pruebas Chi-Cuadrado**
# - >1. Prueba de ***bondad de ajuste***. \\
# Se compara a la distribución observada de los datos con una distribución que se espera en los datos.
# - > 2. Prueba de ***independencia***. \\
# El objetivo es verificar si dos variables cuantitativas son o no independientes.
# (En esta aula NO hablaremos de esta Prueba de Independencia)

# %% [markdown]
# ##<font color='orange'>**Prueba de bondad de ajuste**

# %% [markdown]
# La prueba de bondad de ajuste chi-cuadrado $(\chi^2)$ prueba la hipótesis nula de que no hay diferencia entre las frecuencias observadas de un evento dado y las frecuencias que realmente se esperan para ese evento.

# %% [markdown]
# **Problema**
#
# Antes de cada partido del campeonato nacional de fútbol, ​​se deben revisar las monedas utilizadas por los árbitros para asegurarse de que no estan sesgadas, es decir, que no tiendan a un resultado determinado.
# Para ello, se debe realizar una prueba sencilla antes de cada partido. Esta prueba consiste en lanzar la moneda del juego **50 veces** y contar las frecuencias de las **CARAS** y de las **CRUCES** obtenidas. En la siguiente tabla se muestran los resultados obtenidos en el experimento:
#
# ||CARA|CRUZ|
# |-|-|-|
# |Observado|17|33|
# |Esperado|25|25|
#
# Con un **nivel de significancia del 5%**, ¿es posible decir que la moneda no es honesta, o sea, que es más probable que caiga con la **CARA** volteada para arriba?

# %% [markdown]
# <font color='red'> Aqui el objetivo es verificar si los resultados del experimento indican que la distribución del número caras (o cruces) es binomial con probabilidad de éxito $0,5$.</font>

# %% [markdown]
# Si denotamos por \\
#
# <font color='red'>$f_{cara}$</font> $\Rightarrow$ la frecuencia que sale  <font color='red'>cara</font>,
#
# <font color='blue'>$f_{cruz}$</font> $\Rightarrow$ la frecuencia que sale <font color='blue'>cruz</font>,
#
# podemos plantear las hipótesis como sigue
#
# $
# \begin{cases}
# H_0: f_{cara} = f_{cruce} \,  \\
# H_1: f_{cara} \neq f_{cruce}
# \end{cases}
# $
# **o equivalentemente**
# $
# \begin{cases}
# H_0:p_{caras}=p_{0i} \\
# H_1:p_{caras}\neq p_{0i}
# \end{cases}
# $
#
# en que $p_{cara}$ representa la probabilidad de que salga cara y $p_{0i}$ es la probabilidad especifica para la categoria $i$, $i=1,\ldots,k.$ \\
#
# En este caso <font color='red'>$p_{0i} =  0,5$</font>.

# %% [markdown]
# **Datos del problema**

# %%
# 1°)
f_obs = [17, 33]
f_esp = [25, 25]
significancia = 0.05
confianza = 1 - significancia
k = 2

# %% [markdown]
# <font color='red'>Observación</font>
#
# $f^{esp}_{i} = n\times p_{0i}$,  $i=1,\ldots,k$.
#
# Tenemos que $k=2$, $n=50$ y $p_{0i}=0,50$, luego
#
# $f^{esp}_{1} = 50 \times 0.50 = 25$ \\
# $f^{esp}_{2} = 50 \times 0.50 = 25$

# %% [markdown]
# #### Haciendo cálculos

# %% [markdown]
# <font color='orange'>**Paso 1: Establecer las hipótesis $H_0$ y $H_1$**
#
# $H_0: f_{cara} = f_{cruce}$  \\
#
# $H_1:  f_{cara} \neq f_{cruce}$
#
# siendo $f_{cara}$ la frecuencia de las caras y $f_{cruce}$ la frecuencia de las cruces.

# %% [markdown]
# <font color='orange'>**Paso 2: Fijar el nivel de significancia $\alpha$ de la prueba**
#
# $\alpha =0.05$

# %% [markdown]
# <font color='orange'>**Paso 3: Estadística de Prueba**
#
# $$ \chi^{2} = \sum\limits_{i=1}^{k}\frac{\left(f^{obs}_{i}-f^{esp}_{i}\right)^2}{f^{esp}_{i}}$$

# %%
# 2°)
                   # PRIMERA CATEGORIA           SEGUNDA CATEGORIA
chi_2 = ((f_obs[0] - f_esp[0])**2 / f_esp[0] + ((f_obs[1] - f_esp[1])** 2 / f_esp[1]))
             # 17                                   # 33
chi_2
# Estadistica de Prueba.
# Out:
# 5.12

# %% [markdown]
# <font color='orange'>**Paso 4: Determinar la región crítica**
#
# Distribucion ASIMETRICA de 0 a Infinito.

# %% [markdown]
# ![Region Critica Moneda](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Moneda.png)

# %% [markdown]
# ##<font color='orange'>Obteniendo $\chi^{2}_{\alpha}$

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi.html

# %%
# 3°) Importamos funcion CHI --->

from scipy.stats import chi

# %%
# 4°) Definimos los Grados de Libertad --->

grados_de_libertad = k - 1

# %%
# 5°) Calculamos VALOR CRITICO , X cuadrado de Alpha --->

chi_2_alpha = chi.ppf(confianza, grados_de_libertad)
chi_2_alpha

# NOS DEVUELVE EL VALOR DE X, PERO NECESITAMOS EL VALOR DE X**2.
# Out:
# 1.9599639845400538

# %%
# 6°) Elevamos al cuadrado(**2) para obtener X**2 --->

chi_2_alpha = chi.ppf(confianza, grados_de_libertad)**2
chi_2_alpha

# NOS DEVUELVE EL VALOR DE X**2.
# Out:
# 3.8414588206941245

# %% [markdown]
# <font color='orange'>La Región Crítica es como sigue

# %% [markdown]
# ![Valor Critico Moneda](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Moneda.png)

# %% [markdown]
# <font color='orange'>**Paso 5: Tomar la decisión y concluir**
#
# <font color='red'>¿$\chi^{2} = 5,12$ está en la Región Crítica?</font> o equivalentemente <font color='red'> ¿ $\chi^{2} \geq 3,84$?</font>

# %%
# 7°)

chi_2 >= chi_2_alpha

# NOS DEVUELVE TRUE, RECHAZAMOS LA HIPOTESIS NULA, YA QUE 5.12 DE LA ESTADISTICA DE PRUEBA ES >= A
# 3.84 Y ESTA DENTRO DE LA REGION CRITICA DE RECHAZO.
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$\chi^{2}≥3,84$</font> y por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar $H_0$</font>.

# %% [markdown]
# ![Decision Moneda](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Moneda.png)

# %% [markdown]
# ###<font color='orange'>CRITERIO DEL P-VALOR

# %% [markdown]
# <font color='red'> Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# El p-valor se calcula como, siempre lo vamos a calcular de la misma manera, para ver que tan pequeña es el area de la cola.
#
# <font color='yellow'>$p-\textrm{valor} = P\left(\chi^{2}_{(k-1)} \geq \chi^{2}_{obs}\right)$
#
# χ2(k−1) = a la probabilidad de una estadistica CHI-CUADRADO que fue calculada anteriormente a partir de la muestra

# %%
# 1°)
raiz_chi_2 = np.sqrt(chi_2)
raiz_chi_2
# Out:
# 2.262741699796952

# %%
# 2°)
p_valor = chi.sf(raiz_chi_2, grados_de_libertad)
p_valor   #sf=porque es a la derecha
# Out:
# 0.023651616655356

# %%
# 3°) Comparamos el P_VALOR con el NIVEL de SIGNIFICANCIA --->
p_valor <= significancia
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p$−valor$\leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar  $H_0$</font>.

# %% [markdown]
# <font color='blue'> **Conclusión:** rechazamos la hipótesis nula ($H_0$) y concluimos que las frecuencias observadas y esperadas son diferentes, es decir, la moneda no es honesta y necesita ser reemplazada. </font>

# %% [markdown]
# ### <font color='orange'>Usando biblioteca de Phyton

# %% [markdown]
# <font color='red'> Usando chisquare</font>
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html

# %%
# 1°) Importamos la Funcion CHISQUARE, de la biblioteca SCIPY --->

from scipy.stats import chisquare

# %%
# 2°) Utilizamos la Funcion y dentro de los paretesis le pasamos la Frecuencia Observada y
# la Frencuencia Esperada --->
chisquare(f_obs, f_esp)

# NOS DEVUELVE 2 RESULTADOS, LA ESTADISTICA DE PRUEBA Y EL P_VALOR
# Out:
# Power_divergenceResult(statistic=5.12, pvalue=0.023651616655356)

# %%
# 3°) Visualizamos los valores que calculamos con CHISQUARE independientemente --->
chi2,p_valor = chisquare(f_obs, f_esp)
print(chi2)
print(p_valor)
# Out:
# 5.12
# 0.023651616655356

# %%
# 4°)
p_valor <= significancia

# NOS DEVUELVE TRUE, MISMO VALOR QUE EN FORMA MANUAL
# Out:
# True

# %% [markdown]
# Observe que <font color='red'>$p$−valor$\leq \alpha$</font>, por lo tanto hay suficiente evidencia en la muestra para <font color='red'>rechazar  $H_0$</font>.

# %% [markdown]
# <font color='blue'> **Conclusión:** rechazamos la hipótesis nula ($H_0$) y concluimos que las frecuencias observadas y esperadas son diferentes, es decir, la moneda no es honesta y necesita ser reemplazada. </font>

# %% [markdown]
# ##<font color='orange'> **Generalizando**

# %% [markdown]
# ###<font color='orange'> **Estadística de prueba**
#
# Para evaluar las hipótesis se utiliza la estadística chi-cuadrado:
# $$ \chi^{2} = \sum\limits_{i=1}^{k}\frac{\left(f^{obs}_{i}-f^{esp}_{i}\right)^2}{f^{esp}_{i}},$$
# en que
# >- $f^{obs}_{i}$: es el valor observado en la $i$-esima categoría.
# >- $f^{esp}_{i}$: es el valor que se espera (bajo $H_0$ cierta) en la $i$-esima categoría y se calcula como sigue $f^{esp}_{i} = n\times p_{0i}$, $i,\ldots,k$.
# >- $k$ es el número de categorías.
#
# Asumiendo que $H_0$ es verdadera y para frecuencias observadas y esperadas grandes,  $\chi^{2} \sim \chi^{2}_{(k-1)}$.

# %% [markdown]
# ###<font color='orange'>**Region Crítica**

# %% [markdown]
# ![Region Critica Chi2](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Chi2.png)

# %% [markdown]
# ###<font color='orange'> **$p$-valor**
# El $p$-valor es calculado como:
#
# $$p-\textrm{valor} = P\left(\chi^{2}_{(k-1)} \geq \chi^{2}_{obs}\right)$$
#
# donde $\chi^{2}_{obs}$ es el valor de la estadística de prueba $\chi^{2}$ calculado a partir de los datos. \\
#
# Recuerde que $H_0$ es rechazada si $p$-valor $\leq \alpha$.

# %%
# EJERCICIO AULA --->
# Sobre el p-valor de una prueba Chi-Cuadrado
# Suponiendo que se aplicó una prueba de Chi-Cuadrado para una muestra de tamaño 6 y el estadístico
# de prueba fue 7,45 ¿Cuál sería el p-valor para esta prueba?

from scipy.stats import chi
import numpy as np

chi_2_ = 7.45

raizchi_2_ = np.sqrt(chi_2_)
pvalor = chi.sf(raizchi_2_, df = 5)
print('p-valor =', pvalor.round(4))
# Out:
# p-valor = 0.1893

# %% [markdown]
# # <font color=green>6. PRUEBAS NO PARAMÉTRICAS</font>
# ***

# %% [markdown]
# En las pruebas no paramétricas, no hacemos suposiciones sobre la distribución (de probabilidad) de la que se extraen las observaciones.

# %% [markdown]
# Tipos de pruebas no paramétricas:
#
# > 1. Prueba de **Wilcoxon** \\
#  Se contrasta la hipótesis nula de igualdad de medias de poblaciones dependientes.
# > 2. Prueba de **Mann-Whitney** \\
# Se contrasta la hipótesis nula de igualdad de medias de poblaciones independientes.

# %% [markdown]
# ## <font color='orange'>6.1 **Prueba de Wilcoxon**
#
# Comparación de dos poblaciones - Muestras pareadas
#
# ***

# %% [markdown]
# ### **Problema**

# %% [markdown]
# Un nuevo tratamiento para acabar con el hábito de fumar esta siendo empleado en un grupo de **35 pacientes** voluntarios. **De cada voluntario** sometido a la prueba se obtuvo información sobre la cantidad de cigarrillos consumidos por día **antes** y **después** del final del tratamiento. Asumiendo un **nivel de confianza del 95%** ¿es posible concluir que, después de la aplicación del nuevo tratamiento, hubo un cambio en el habito de fumar en el grupo de pacientes evaluados?

# %% [markdown]
# <font color='orange'>Si denotamos por \\
#
# $\mu_{antes} \Rightarrow$ la media de cigarrillos consumidos antes del tratamiento,
#
# $\mu_{despues} \Rightarrow$ la media de cigarrillos consumidos despues del tratamiento,
#
# podemos plantear las hipótesis como sigue
#
# <font color='yellow'>$
# \begin{cases}
# H_0: \mu_{antes} = \mu_{despues} \,  \\
# H_1: \mu_{antes} \neq \mu_{despues}
# \end{cases}
# $

# %% [markdown]
# **Datos del problema**

# %%
# 1°) Datos del problema, el antes y despues en la lista con los valores que nos dala profesora, cada individuo con los
# valores de antes y despues del tratamiento --->

fumar = {'Antes': [39, 25, 24, 50, 13, 52, 21, 29, 10, 22, 50, 15, 36, 39, 52, 48, 24, 15, 40, 41, 17, 12, 21, 49, 14, 55, 46, 22, 28, 23, 37, 17, 31, 49, 49],
         'Despues':[16, 8, 12,  0, 14, 16, 13, 12, 19, 17, 17,  2, 15, 10, 20, 13,  0,  4, 16, 18, 16, 16,  9,  9, 18,  4, 17,  0, 11, 14,  0, 19,  2,  9,  6 ]}
significancia = 0.05
confianza  = 1  - significancia
n = 35

# %%
# 2°) Creamos DataFrame FUMAR -->
fumar = pd.DataFrame(fumar)
fumar
# Out:
#     Antes  Despues
# 0      39       16
# 1      25        8
# 2      24       12
# 3      50        0
# 4      13       14
# 5      52       16
# 6      21       13
# 7      29       12
# 8      10       19
# 9      22       17
# 10     50       17
# 11     15        2
# 12     36       15
# 13     39       10
# 14     52       20
# 15     48       13
# 16     24        0
# 17     15        4
# 18     40       16
# 19     41       18
# 20     17       16
# 21     12       16
# 22     21        9
# 23     49        9
# 24     14       18
# 25     55        4
# 26     46       17
# 27     22        0
# 28     28       11
# 29     23       14
# 30     37        0
# 31     17       19
# 32     31        2
# 33     49        9
# 34     49        6

# %% [markdown]
# #### Haciendo cálculos

# %% [markdown]
# <font color='orange'>**Paso 1: Establecer las hipótesis $H_0$ y $H_1$**
#
# $\mu_{antes} \Rightarrow$ la media de cigarrillos consumidos antes del tratamiento,
#
# $\mu_{despues} \Rightarrow$ la media de cigarrillos consumidos despues del tratamiento.
#
#
# $
# \begin{cases}
# H_0: \mu_{antes} = \mu_{despues} \,  \\
# H_1: \mu_{antes} \neq \mu_{despues}
# \end{cases}
# $

# %% [markdown]
# **Paso 2: Fijar el nivel de  significancia $\alpha$ de la prueba**
#
# $\alpha=0.05$

# %% [markdown]
# <font color='orange'>**Paso 3: Calcular la Estadística de Prueba**
#
# <font color='yellow'>$$Z = \frac{T - \mu_{T}}{\sigma_{T}},$$
#
# en que $T$ es la menor de las sumas de rangos del mismo signo y
# <font color='yellow'>$$\mu_{T} = \frac{n(n+1)}{4},$$
#
# <font color='yellow'>$$ \sigma_{T} = \sqrt{\frac{n(n+1)(2n+1)}{24}}. $$

# %% [markdown]
# ##<font color='orange'>Calculando $T$

# %%
# 3°) Vemos la informacion de los 35 individuos creado en el DATAFRAME --->
fumar
# Out:
#     Antes  Despues
# 0      39       16
# 1      25        8
# 2      24       12
# 3      50        0
# 4      13       14
# 5      52       16
# 6      21       13
# 7      29       12
# 8      10       19
# 9      22       17
# 10     50       17
# 11     15        2
# 12     36       15
# 13     39       10
# 14     52       20
# 15     48       13
# 16     24        0
# 17     15        4
# 18     40       16
# 19     41       18
# 20     17       16
# 21     12       16
# 22     21        9
# 23     49        9
# 24     14       18
# 25     55        4
# 26     46       17
# 27     22        0
# 28     28       11
# 29     23       14
# 30     37        0
# 31     17       19
# 32     31        2
# 33     49        9
# 34     49        6

# %%
# 4°) Luego, tenemos que hacer la DIFERENCIA entre el antes y despues y lo creamos en una COLUMNA en forma
# de VARIABLE --->
fumar["Dif"] = fumar.Despues - fumar.Antes
fumar
# Out:
#     Antes  Despues  Dif
# 0      39       16  -23
# 1      25        8  -17
# 2      24       12  -12
# 3      50        0  -50
# 4      13       14    1
# 5      52       16  -36
# 6      21       13   -8
# 7      29       12  -17
# 8      10       19    9
# 9      22       17   -5
# 10     50       17  -33
# 11     15        2  -13
# 12     36       15  -21
# 13     39       10  -29
# 14     52       20  -32
# 15     48       13  -35
# 16     24        0  -24
# 17     15        4  -11
# 18     40       16  -24
# 19     41       18  -23
# 20     17       16   -1
# 21     12       16    4
# 22     21        9  -12
# 23     49        9  -40
# 24     14       18    4
# 25     55        4  -51
# 26     46       17  -29
# 27     22        0  -22
# 28     28       11  -17
# 29     23       14   -9
# 30     37        0  -37
# 31     17       19    2
# 32     31        2  -29
# 33     49        9  -40
# 34     49        6  -43

# %%
# 5°) Sacamos los SIGNOS negativos de la columna DIF calculando el VALOR ABSOLUTO de |DIF|--->
fumar["|Dif|"] = fumar.Dif.abs()
fumar
# Out:
#     Antes  Despues  Dif  |Dif|
# 0      39       16  -23     23
# 1      25        8  -17     17
# 2      24       12  -12     12
# 3      50        0  -50     50
# 4      13       14    1      1
# 5      52       16  -36     36
# 6      21       13   -8      8
# 7      29       12  -17     17
# 8      10       19    9      9
# 9      22       17   -5      5
# 10     50       17  -33     33
# 11     15        2  -13     13
# 12     36       15  -21     21
# 13     39       10  -29     29
# 14     52       20  -32     32
# 15     48       13  -35     35
# 16     24        0  -24     24
# 17     15        4  -11     11
# 18     40       16  -24     24
# 19     41       18  -23     23
# 20     17       16   -1      1
# 21     12       16    4      4
# 22     21        9  -12     12
# 23     49        9  -40     40
# 24     14       18    4      4
# 25     55        4  -51     51
# 26     46       17  -29     29
# 27     22        0  -22     22
# 28     28       11  -17     17
# 29     23       14   -9      9
# 30     37        0  -37     37
# 31     17       19    2      2
# 32     31        2  -29     29
# 33     49        9  -40     40
# 34     49        6  -43     43

# %%
# 6°) Luego, ordenamos de forma Ascendente conforme el VALOR ABSOLUTO de la Diferencia, de menor a mayor --->

fumar.sort_values(by = "|Dif|", inplace = True) # inplace=True, para que sea efectiva la modificacion
fumar
# Out:
#     Antes  Despues  Dif  |Dif|
# 4      13       14    1      1
# 20     17       16   -1      1
# 31     17       19    2      2
# 21     12       16    4      4
# 24     14       18    4      4
# 9      22       17   -5      5
# 6      21       13   -8      8
# 29     23       14   -9      9
# 8      10       19    9      9
# 17     15        4  -11     11
# 2      24       12  -12     12
# 22     21        9  -12     12
# 11     15        2  -13     13
# 28     28       11  -17     17
# 1      25        8  -17     17
# 7      29       12  -17     17
# 12     36       15  -21     21
# 27     22        0  -22     22
# 19     41       18  -23     23
# 0      39       16  -23     23
# 16     24        0  -24     24
# 18     40       16  -24     24
# 26     46       17  -29     29
# 13     39       10  -29     29
# 32     31        2  -29     29
# 14     52       20  -32     32
# 10     50       17  -33     33
# 15     48       13  -35     35
# 5      52       16  -36     36
# 30     37        0  -37     37
# 33     49        9  -40     40
# 23     49        9  -40     40
# 34     49        6  -43     43
# 3      50        0  -50     50
# 25     55        4  -51     51

# %%
# 7°) Creamos una Variable RANGO, que es un conteo, identificador o INDICE --->
fumar["Rango"] = range(1, len(fumar) + 1)
fumar
# Out:
#     Antes  Despues  Dif  |Dif|  Rango
# 4      13       14    1      1      1
# 20     17       16   -1      1      2
# 31     17       19    2      2      3
# 21     12       16    4      4      4
# 24     14       18    4      4      5
# 9      22       17   -5      5      6
# 6      21       13   -8      8      7
# 29     23       14   -9      9      8
# 8      10       19    9      9      9
# 17     15        4  -11     11     10
# 2      24       12  -12     12     11
# 22     21        9  -12     12     12
# 11     15        2  -13     13     13
# 28     28       11  -17     17     14
# 1      25        8  -17     17     15
# 7      29       12  -17     17     16
# 12     36       15  -21     21     17
# 27     22        0  -22     22     18
# 19     41       18  -23     23     19
# 0      39       16  -23     23     20
# 16     24        0  -24     24     21
# 18     40       16  -24     24     22
# 26     46       17  -29     29     23
# 13     39       10  -29     29     24
# 32     31        2  -29     29     25
# 14     52       20  -32     32     26
# 10     50       17  -33     33     27
# 15     48       13  -35     35     28
# 5      52       16  -36     36     29
# 30     37        0  -37     37     30
# 33     49        9  -40     40     31
# 23     49        9  -40     40     32
# 34     49        6  -43     43     33
# 3      50        0  -50     50     34
# 25     55        4  -51     51     35

# %%
# 8°) Sacamos la MEDIA DE RANGO en donde el DIF este REPETIDA --->

rango = fumar[["|Dif|", "Rango"]].groupby(["|Dif|"]).mean()
rango       # Tomamos Rango y |Dif|. agrupamos por |Dif|. y le calculamos la MEDIA

# NOS DEVUELVE LA MEDIA DE LOS NUMEROS REPETIDOS EN |DIF|, EJEMPLO, EN 1 ESTABA REPETIDO 2 VECES.
# Out:
#        Rango
# |Dif|
# 1        1.5
# 2        3.0
# 4        4.5
# 5        6.0
# 8        7.0
# 9        8.5
# 11      10.0
# 12      11.5
# 13      13.0
# 17      15.0
# 21      17.0
# 22      18.0
# 23      19.5
# 24      21.5
# 29      24.0
# 32      26.0
# 33      27.0
# 35      28.0
# 36      29.0
# 37      30.0
# 40      31.5
# 43      33.0
# 50      34.0
# 51      35.0

# %%
# 9°) Como vamos a usar la Variable del VALOR ABSOLUTO de |DIF|, lo vamos a transformar en un INDICE --->

rango.reset_index(inplace = True)
rango
# Out:
#     |Dif|  Rango
# 0       1    1.5
# 1       2    3.0
# 2       4    4.5
# 3       5    6.0
# 4       8    7.0
# 5       9    8.5
# 6      11   10.0
# 7      12   11.5
# 8      13   13.0
# 9      17   15.0
# 10     21   17.0
# 11     22   18.0
# 12     23   19.5
# 13     24   21.5
# 14     29   24.0
# 15     32   26.0
# 16     33   27.0
# 17     35   28.0
# 18     36   29.0
# 19     37   30.0
# 20     40   31.5
# 21     43   33.0
# 22     50   34.0
# 23     51   35.0

# %%
# 10°) Para evitar conflictos con los Nombres rango y Rango, ya que esta con mayuscula y minuscula , borramos Rango --->

fumar.drop(['Rango'],axis=1, inplace=True)
fumar
# Out:
#     Antes  Despues  Dif  |Dif|
# 4      13       14    1      1
# 20     17       16   -1      1
# 31     17       19    2      2
# 21     12       16    4      4
# 24     14       18    4      4
# 9      22       17   -5      5
# 6      21       13   -8      8
# 29     23       14   -9      9
# 8      10       19    9      9
# 17     15        4  -11     11
# 2      24       12  -12     12
# 22     21        9  -12     12
# 11     15        2  -13     13
# 28     28       11  -17     17
# 1      25        8  -17     17
# 7      29       12  -17     17
# 12     36       15  -21     21
# 27     22        0  -22     22
# 19     41       18  -23     23
# 0      39       16  -23     23
# 16     24        0  -24     24
# 18     40       16  -24     24
# 26     46       17  -29     29
# 13     39       10  -29     29
# 32     31        2  -29     29
# 14     52       20  -32     32
# 10     50       17  -33     33
# 15     48       13  -35     35
# 5      52       16  -36     36
# 30     37        0  -37     37
# 33     49        9  -40     40
# 23     49        9  -40     40
# 34     49        6  -43     43
# 3      50        0  -50     50
# 25     55        4  -51     51

# %%
# 11°) Luego, juntamos el OBJETO FUMAR con rango(minuscula), usando como enlace la Variable |DIF| --->

fumar = fumar.merge(rango, left_on='|Dif|', right_on='|Dif|',how='left')
fumar
# Out:
#     Antes  Despues  Dif  |Dif|  Rango
# 0      13       14    1      1    1.5
# 1      17       16   -1      1    1.5
# 2      17       19    2      2    3.0
# 3      12       16    4      4    4.5
# 4      14       18    4      4    4.5
# 5      22       17   -5      5    6.0
# 6      21       13   -8      8    7.0
# 7      23       14   -9      9    8.5
# 8      10       19    9      9    8.5
# 9      15        4  -11     11   10.0
# 10     24       12  -12     12   11.5
# 11     21        9  -12     12   11.5
# 12     15        2  -13     13   13.0
# 13     28       11  -17     17   15.0
# 14     25        8  -17     17   15.0
# 15     29       12  -17     17   15.0
# 16     36       15  -21     21   17.0
# 17     22        0  -22     22   18.0
# 18     41       18  -23     23   19.5
# 19     39       16  -23     23   19.5
# 20     24        0  -24     24   21.5
# 21     40       16  -24     24   21.5
# 22     46       17  -29     29   24.0
# 23     39       10  -29     29   24.0
# 24     31        2  -29     29   24.0
# 25     52       20  -32     32   26.0
# 26     50       17  -33     33   27.0
# 27     48       13  -35     35   28.0
# 28     52       16  -36     36   29.0
# 29     37        0  -37     37   30.0
# 30     49        9  -40     40   31.5
# 31     49        9  -40     40   31.5
# 32     49        6  -43     43   33.0
# 33     50        0  -50     50   34.0
# 34     55        4  -51     51   35.0

# %%
# 12°) Paso final, vamos a colocar los rangos POSITIVOS y NEGATIVOS para la Diferencia de DIF, vamos a usar la Funcion
# APPLY() y dentro de ella la Funcion LAMBDA(), donde vamos a atribuirle el valor de rango correspondiente al DIF que son
# mayores a 0, en caso(else) contrario atribuimos 0 --->

fumar["Rango (+)"] = fumar.apply(lambda x: x.Rango if x.Dif > 0 else 0, axis=1)#axis=1,para que haga esto en toda la fila
fumar
# Out:
#     Antes  Despues  Dif  |Dif|  Rango  Rango (+)
# 0      13       14    1      1    1.5        1.5
# 1      17       16   -1      1    1.5        0.0
# 2      17       19    2      2    3.0        3.0
# 3      12       16    4      4    4.5        4.5
# 4      14       18    4      4    4.5        4.5
# 5      22       17   -5      5    6.0        0.0
# 6      21       13   -8      8    7.0        0.0
# 7      23       14   -9      9    8.5        0.0
# 8      10       19    9      9    8.5        8.5
# 9      15        4  -11     11   10.0        0.0
# 10     24       12  -12     12   11.5        0.0
# 11     21        9  -12     12   11.5        0.0
# 12     15        2  -13     13   13.0        0.0
# 13     28       11  -17     17   15.0        0.0
# 14     25        8  -17     17   15.0        0.0
# 15     29       12  -17     17   15.0        0.0
# 16     36       15  -21     21   17.0        0.0
# 17     22        0  -22     22   18.0        0.0
# 18     41       18  -23     23   19.5        0.0
# 19     39       16  -23     23   19.5        0.0
# 20     24        0  -24     24   21.5        0.0
# 21     40       16  -24     24   21.5        0.0
# 22     46       17  -29     29   24.0        0.0
# 23     39       10  -29     29   24.0        0.0
# 24     31        2  -29     29   24.0        0.0
# 25     52       20  -32     32   26.0        0.0
# 26     50       17  -33     33   27.0        0.0
# 27     48       13  -35     35   28.0        0.0
# 28     52       16  -36     36   29.0        0.0
# 29     37        0  -37     37   30.0        0.0
# 30     49        9  -40     40   31.5        0.0
# 31     49        9  -40     40   31.5        0.0
# 32     49        6  -43     43   33.0        0.0
# 33     50        0  -50     50   34.0        0.0
# 34     55        4  -51     51   35.0        0.0

# %%
# Hacemos los mismo pero para los Nehativos --->

fumar["Rango (-)"] = fumar.apply(lambda x: x.Rango if x.Dif < 0 else 0, axis=1)#axis=1,para que haga esto en toda la fila
fumar
# Out:
#     Antes  Despues  Dif  |Dif|  Rango  Rango (+)  Rango (-)
# 0      13       14    1      1    1.5        1.5        0.0
# 1      17       16   -1      1    1.5        0.0        1.5
# 2      17       19    2      2    3.0        3.0        0.0
# 3      12       16    4      4    4.5        4.5        0.0
# 4      14       18    4      4    4.5        4.5        0.0
# 5      22       17   -5      5    6.0        0.0        6.0
# 6      21       13   -8      8    7.0        0.0        7.0
# 7      23       14   -9      9    8.5        0.0        8.5
# 8      10       19    9      9    8.5        8.5        0.0
# 9      15        4  -11     11   10.0        0.0       10.0
# 10     24       12  -12     12   11.5        0.0       11.5
# 11     21        9  -12     12   11.5        0.0       11.5
# 12     15        2  -13     13   13.0        0.0       13.0
# 13     28       11  -17     17   15.0        0.0       15.0
# 14     25        8  -17     17   15.0        0.0       15.0
# 15     29       12  -17     17   15.0        0.0       15.0
# 16     36       15  -21     21   17.0        0.0       17.0
# 17     22        0  -22     22   18.0        0.0       18.0
# 18     41       18  -23     23   19.5        0.0       19.5
# 19     39       16  -23     23   19.5        0.0       19.5
# 20     24        0  -24     24   21.5        0.0       21.5
# 21     40       16  -24     24   21.5        0.0       21.5
# 22     46       17  -29     29   24.0        0.0       24.0
# 23     39       10  -29     29   24.0        0.0       24.0
# 24     31        2  -29     29   24.0        0.0       24.0
# 25     52       20  -32     32   26.0        0.0       26.0
# 26     50       17  -33     33   27.0        0.0       27.0
# 27     48       13  -35     35   28.0        0.0       28.0
# 28     52       16  -36     36   29.0        0.0       29.0
# 29     37        0  -37     37   30.0        0.0       30.0
# 30     49        9  -40     40   31.5        0.0       31.5
# 31     49        9  -40     40   31.5        0.0       31.5
# 32     49        6  -43     43   33.0        0.0       33.0
# 33     50        0  -50     50   34.0        0.0       34.0
# 34     55        4  -51     51   35.0        0.0       35.0

# %%
# 13°) Ahora quitamos Rango --->

fumar.drop(["Rango"], axis=1, inplace=True)
fumar
# Out:
#     Antes  Despues  Dif  |Dif|  Rango (+)  Rango (-)
# 0      13       14    1      1        1.5        0.0
# 1      17       16   -1      1        0.0        1.5
# 2      17       19    2      2        3.0        0.0
# 3      12       16    4      4        4.5        0.0
# 4      14       18    4      4        4.5        0.0
# 5      22       17   -5      5        0.0        6.0
# 6      21       13   -8      8        0.0        7.0
# 7      23       14   -9      9        0.0        8.5
# 8      10       19    9      9        8.5        0.0
# 9      15        4  -11     11        0.0       10.0
# 10     24       12  -12     12        0.0       11.5
# 11     21        9  -12     12        0.0       11.5
# 12     15        2  -13     13        0.0       13.0
# 13     28       11  -17     17        0.0       15.0
# 14     25        8  -17     17        0.0       15.0
# 15     29       12  -17     17        0.0       15.0
# 16     36       15  -21     21        0.0       17.0
# 17     22        0  -22     22        0.0       18.0
# 18     41       18  -23     23        0.0       19.5
# 19     39       16  -23     23        0.0       19.5
# 20     24        0  -24     24        0.0       21.5
# 21     40       16  -24     24        0.0       21.5
# 22     46       17  -29     29        0.0       24.0
# 23     39       10  -29     29        0.0       24.0
# 24     31        2  -29     29        0.0       24.0
# 25     52       20  -32     32        0.0       26.0
# 26     50       17  -33     33        0.0       27.0
# 27     48       13  -35     35        0.0       28.0
# 28     52       16  -36     36        0.0       29.0
# 29     37        0  -37     37        0.0       30.0
# 30     49        9  -40     40        0.0       31.5
# 31     49        9  -40     40        0.0       31.5
# 32     49        6  -43     43        0.0       33.0
# 33     50        0  -50     50        0.0       34.0
# 34     55        4  -51     51        0.0       35.0

# %% [markdown]
# <font color='orange'>$T$ es la menor de las sumas de rangos del mismo signo

# %%
# 14°)

T = min(fumar["Rango (+)"].sum(), fumar["Rango (-)"].sum())
T

# EL NUMERO DE LOS 2 VALORES ES 22
# Out:
# 22.0

# %% [markdown]
# <font color='orange'>Calculamos $\mu_{T}$:
#
# $$\mu_{T} = \frac{n(n+1)}{4},$$

# %%
# 1°)

mu_T = (n*(n + 1))/4
mu_T
# Out:
# 315.0

# %% [markdown]
# <font color='orange'>Calculamos $\sigma_{T}$
#
# $$ \sigma_{T} = \sqrt{\frac{n(n+1)(2n+1)}{24}} $$

# %%
# 2°)

sigma_T = np.sqrt((n*(n + 1) * (2* n + 1)) / 24)
sigma_T
# Out:
# 61.053255441458646

# %% [markdown]
# <font color='orange'>Calculamos $Z$:
#
# $$Z = \frac{T - \mu_{T}}{\sigma_{T}}$$

# %%
# 3°)

Z = (T - mu_T) / sigma_T
Z
# Out:
# -4.799088891843698

# %% [markdown]
# <font color='orange'>**Paso 4: Determinar la región crítica**

# %% [markdown]
# ![Region Critica Bilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Bilateral.png)

# %% [markdown]
# <font color='orange'>Obteniendo $z_{\alpha/2}$

# %%
# 1°) Importamos Funcion NORM de SCIPY --->

from scipy.stats import norm

# %%
# 2°)

z_alpha_2 = norm.ppf(0.975)
z_alpha_2
# Out:
# 1.959963984540054

# %% [markdown]
# <font color='orange'>Por lo tanto la región crítica es

# %% [markdown]
# ![Valor Critico Bilateral](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Bilateral.png)

# %% [markdown]
# <font color='orange'>**Paso 5: Tomar la decisión y concluir**

# %% [markdown]
# <font color='red'>¿$Z = -4,80$ está en la Región Crítica?</font> o equivalentemente <font color='red'> ¿ $Z \geq 1,96$ o $Z\leq -1,96$?</font>

# %%
# 3°)

Z <= -z_alpha_2

# NOS DEVUELVE TRUE, POR LO TANTO RECHAZAMOS LA HIPOTESIS NULA Y ACEPTAMOS H1, LOS GRUPOS SON DIFERENTES ANTES Y DESPUES.
# Out:
# True

# %% [markdown]
# Observe que $Z\leq -1,96$ y por lo tanto hay suficiente evidencia en la muestra para rechazar $H_0$.

# %% [markdown]
# ![Decision Fumar](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Fumar.png)

# %% [markdown]
# ###<font color='orange'> **CRITERIO P-VALOR**

# %% [markdown]
# <font color='red'>Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# #### Usando biblioteca de Phyton (**FORMA SIMPLE**)
# Sin necesidad de hacer todo lo calculado anteriormente

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html

# %%
# 1°) Importamos Funcion WILCOXON de la biblioteca SCIPY --->
from scipy.stats import wilcoxon

# %%
# 2°)
wilcoxon(fumar.Antes, fumar.Despues)
# Out:
# WilcoxonResult(statistic=22.0, pvalue=3.119930624961853e-08)

# %%
# 3°) Los separamos para que los valores esten independientes --->
T, p_valor = wilcoxon(fumar.Antes,fumar.Despues)
print(T)
print(p_valor)
# Out:
# 22.0
# 3.119930624961853e-08

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
#  <font color='blue'>**Conclusión**: Rechazamos la hipótesis de que no hay diferencia entre grupos, es decir, hay diferencia entre el número promedio de cigarrillos fumados por los pacientes antes y después del tratamiento. Y como se puede comprobar a través del promedio de cigarrillos fumados por día antes (31,86) y después (11,2) del tratamiento, podemos concluir que el tratamiento presentó un resultado satisfactorio.</font>

# %%
# Codigo creado por AI, para sacar la media que nos devuelve la conclucion de arriba --->
f_antes = np.array(fumar['Antes'])
f_despues = np.array(fumar['Despues'])
promedio_antes = f_antes.mean()
promedio_despues = f_despues.mean()
print(promedio_antes)
print(promedio_despues)
# Out:
# 31.857142857142858
# 11.2

# %% [markdown]
# ### <font color='orange'> **Generalizando**

# %% [markdown]
# #### <font color='orange'> **Hipótesis**
# > Prueba <font color ='red'> Bilateral </font> $\hspace{2.3 cm}$
# $
# \begin{cases}
# H_0: \mu_1 = \mu_2\\
# H_1: \mu_1 \neq \mu_2
# \end{cases}
# $
#
# > Prueba  <font color ='red'>Unilateral a Derecha</font>$\hspace{0.2 cm}$
# $
# \begin{cases}
# H_0: \mu_1 \leq \mu_2\\
# H_1: \mu_1 > \mu_2
# \end{cases}
# $
#
# > Prueba <font color ='red'> Unilateral a Izquierda </font>
# $
# \begin{cases}
# H_0: \mu_1 \geq \mu_2\\
# H_1: \mu_1 < \mu_2
# \end{cases}
# $

# %% [markdown]
# #### <font color='orange'> **Estadística de prueba**
#
# $$Z = \frac{T - \mu_{T}}{\sigma_{T}},$$
#
# <font color='orange'> en que $T$ es la menor de las sumas de rangos del mismo signo y
#
# $$\mu_{T} = \frac{n(n+1)}{4},$$
#
# $$ \sigma_{T} = \sqrt{\frac{n(n+1)(2n+1)}{24}}. $$

# %% [markdown]
# #### **Región Crítica**

# %% [markdown]
# ![Region Critica NP](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_NP.png)

# %% [markdown]
# #### <font color='orange'> **$p$-valor**

# %% [markdown]
# Asumiendo que $W$ es una estadística de prueba  cualquiera (calculada bajo $H_0$ cierta), el $p$-valor es calculado como sigue:
#
# >- Prueba <font color='red'>Bilateral $(H_1: \mu_{1} \neq \mu_{2})$</font>
#
# $$p-\textrm{valor}= 2\times P(W \geq Z) = 2\times [1-P(W < Z) ] $$.
#
# >- Prueba <font color='red'>Unilateral a Derecha $(H_1: \mu_{1} > \mu_{2})$</font>
#
# $$p-\textrm{valor}= P(W \geq Z)= 1-P(W < Z)$$
#
# >- Prueba <font color='red'>Unilateral a Izquierda $(H_1: \mu_{1} < \mu_{2})$</font>
#
# $$p-\textrm{valor}= P(W \leq Z)$$.

# %%
# EJEMPLO AULA --->
# Sospechando de la eficiencia de los cursos en línea y los materiales de estudio de Alura, un maestro decidió tomar una prueba
# con un grupo de 14 estudiantes en su clase. Para ello, sometió a estos estudiantes a dos etapas distintas e inmediatamente después
# de cada etapa, aplicó una evaluación. En la etapa inicial, se ofrecieron clases normales, sin utilizar el material de apoyo de Alura.
# En la segunda etapa también se ofrecieron clases normales, pero utilizando el material de apoyo de Alura. Las calificaciones obtenidas
# por los estudiantes se muestran en la siguiente tabla:

#
#Estudiante	Sin Alura	Con Alura
#  A 	          7	      10
#  B	          8	      10
#  C	          6	       9
#  D	          6	       9
#  E	          10	     9
#  F	          4	       7
#  G	          2	       5
#  H	          5	       8
#  I	          9	      10
#  J	          2	       6
#  K	          4	       3
#  L	          9	       7
#  M	          1	       4
#  N	         10	       8

# alternativa que presenta el resultado de la prueba, no paramétrica de Wilcoxon, aplicada por el profesor
# (estadística de la prueba T y decisión de la prueba). Considere un nivel de significancia del 10%.

estudiantes= {'sin_alura': [7, 8, 6, 6, 10, 4, 2, 5, 9, 2, 4, 9, 1, 10],
         'con_alura':[10, 10, 9, 9, 9, 7, 5, 8, 10, 6, 3, 7, 4, 8 ]}
signif = 0.10
confianza  = 1  - signif
n = 14

estudiantes = pd.DataFrame(estudiantes)
estudiantes

wilcoxon(estudiantes.sin_alura, estudiantes.con_alura)

T, p_value = wilcoxon(estudiantes.sin_alura, estudiantes.con_alura)
print(T)
print(p_value)
# Out:
# 14.0
# 0.013427734375

# %%
if(p_valor <= significancia):
  print('Rechazar H0')
else:
  print('No rechazar H0')

# Rechazar H_0, es decir, hay una diferencia significativa en la puntuación media del grupo después de utilizar el material de apoyo de Alura.

# Dado que la nota media con el uso del material de apoyo de Alura fue superior (7,5 con Alura y 5,93 sin Alura), se puede decir que el uso de material online
# tiene un efecto positivo en el aprendizaje de los alumnos. Aquí está el código de la solución:
# Out:
# Rechazar H0

# %%
# Codigo creado por AI, para sacar la media que nos devuelve la conclucion de arriba --->

promedio_antes = estudiantes.sin_alura.mean()
promedio_despues = estudiantes.con_alura.mean()
print(promedio_antes)
print(promedio_despues)
# Out:
# 5.928571428571429
# 7.5

# %% [markdown]
# ##<font color='orange'> 6.2 **Prueba de Mann-Whitney**
#
# Comparación de dos poblaciones - Muestras independientes
#
# ***

# %% [markdown]
# ### **Problema**

# %% [markdown]
# En nuestro conjunto de datos de la **Encuesta Nacional por Muestra de Hogares - 2015** tenemos los ingresos de los jefes de hogar. Un problema bastante conocido en Brasil es la **desigualdad de ingresos**, especialmente entre hombres y mujeres.
#
# Dos muestras al azar, uno de **6 hombres** y uno de **8 mujeres**, fueron seleccionados en nuestro conjunto de datos. Para probar esta desigualdad, **pruebe la igualdad de medias entre estas dos muestras con un nivel de significancia del 5%**

# %% [markdown]
# Si denotamos por \\
# <font color='blue'> $\mu_m$ </font> $\Rightarrow$ el ingreso medio de los jefes del hogar de género <font color='blue'>femenino</font>. \\
# <font color='red'>$\mu_h$</font> $\Rightarrow$ el ingreso medio de los jefes del hogar de género <font color='red'>masculino</font>, \\
#
# las hipótesis que queremos probar son
# $
# \begin{cases}
# H_0: \mu_m \geq \mu_h\\
# H_1: \mu_m < \mu_h
# \end{cases}
# $

# %% [markdown]
# **Seleccionando las muestras**

# %%
# 1°) Seleccionamos Muestras, 6 para los HOMBRES y 8 para las MUJERES --->

muestra_hombres = datos.query("Sexo == 0").sample(n = 6, random_state = 1010).Renta

# Random_state para que seleccione siempre los mismos datos para la muestra(para no varie cada vez que lo ejecutemos)
# sample= muestra

# %%
muestra_mujeres = datos.query("Sexo == 1").sample(n = 8, random_state = 1010).Renta

# %%
# 2°) Calculamos la MEDIA de cada una de las MUESTRAS, para comparar los salarios y tener una idea se eta diferencia
# se cumple o NO se cumple --->

media_muestral_H = muestra_hombres.mean()
media_muestral_H
# Nos devuelve lo que ganan los hombres
# Out:
# 3633.3333333333335

# %%
media_muestral_M = muestra_mujeres.mean()
media_muestral_M
# Nos devuelve lo que ganan las mujeres
# Out:
# 598.5

# %% [markdown]
# **Datos del problema**

# %%
# 3°)
significancia = 0.05
confianza = 1 - significancia
n_1 = len(muestra_hombres)
n_2 = len(muestra_mujeres)

# %% [markdown]
# #### Haciendo cálculos

# %% [markdown]
# <font color='orange'> **Paso 1: Establecer las hipótesis $H_0$ y $H_1$**
#
# <font color='blue'> $\mu_m$ </font> $\Rightarrow$ el ingreso medio de los jefes del hogar de género <font color='blue'>femenino</font>. \\
# <font color='red'>$\mu_h$</font> $\Rightarrow$ el ingreso medio de los jefes del hogar de género <font color='red'>masculino</font>. \\
#
# $
# \begin{cases}
# H_0: \mu_m = \mu_h \\
# H_1: \mu_m < \mu_h
# \end{cases}
# $

# %% [markdown]
# <font color='orange'> **Paso 2: Fijar el nivel de  significancia $\alpha$ de la prueba**
#
# $\alpha=0.05$

# %% [markdown]
# <font color='orange'>  **Paso 3: Calcular la Estadística de Prueba**

# %% [markdown]
# <font color='yellow'>$$Z = \frac{u - \mu{(u)}}{\sigma{(u)}},$$
#
# donde
#
# > $u = min(u_1, u_2)$
# >- $u_1 = n_1 \times n_2 + \frac{n_1 \times (n_1 + 1)}{2} - R_1$
# >- $u_2 = n_1 \times n_2 + \frac{n_2 \times (n_2 + 1)}{2} - R_2$
# >- $n_1$ = nº de elementos del grupo más pequeño (hombres)
# >- $n_2$ = nº de elementos del grupo más grande (mujeres)
# >- $R_1$ = suma de los rangos del grupo $n_1$
# >- $R_2$ = suma de los rangos del grupo $n_2$
#
# > $\mu{(u)} = \frac{n_1 \times n_2}{2}$
#
# > $\sigma{(u)} = \sqrt{\frac{n_1 \times n_2 \times (n_1 + n_2 + 1)}{12}}$

# %% [markdown]
# <font color='orange'> Calculando $R_1$ y $R_2$

# %%
# 4°) Primero debemos construir una TABLA, creamos un archivo H de hombres y colocamos un DATAFRAME de la muestra hombre
# y colocamos informaciones en ella de los hombres y creamos la variable SEXO de que ahi tenemos hombres --->

H = pd.DataFrame(muestra_hombres)
H["Sexo"] = "Hombres"
H
# Nos devuelve las 6 muestras Aleatorias
# Out:
#        Renta     Sexo
# 696      800  Hombres
# 59541   5000  Hombres
# 40800   1600  Hombres
# 41986   1200  Hombres
# 52349  12000  Hombres
# 27443   1200  Hombres

# %%
M = pd.DataFrame(muestra_mujeres)
M["Sexo"] = "Mujeres"
M
# Nos devuelve las 8 muestras Aleatorias
# Out:
#        Renta     Sexo
# 38880    800  Mujeres
# 44988    600  Mujeres
# 54310   1200  Mujeres
# 43236    900  Mujeres
# 74741    788  Mujeres
# 10600    350  Mujeres
# 4611       0  Mujeres
# 1638     150  Mujeres

# %%
# 5°) Ahora colocamos esos 2 archivos en uno solo --->

Sexo = H.append(M) # al archivo hombre le coloco el de Mujeres con APPEND
Sexo.reset_index(inplace = True, drop = True) # sacamos la columna de valores de muestra
Sexo
# Out:
# <ipython-input-139-114a4477f221>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Sexo = H.append(M) # al archivo hombre le coloco el de Mujeres con APPEND
#     Renta     Sexo
# 0     800  Hombres
# 1    5000  Hombres
# 2    1600  Hombres
# 3    1200  Hombres
# 4   12000  Hombres
# 5    1200  Hombres
# 6     800  Mujeres
# 7     600  Mujeres
# 8    1200  Mujeres
# 9     900  Mujeres
# 10    788  Mujeres
# 11    350  Mujeres
# 12      0  Mujeres
# 13    150  Mujeres

# %%
# 6°) Ordenamos de forma Ascendente, de menor a mayor la renta --->

Sexo.sort_values(by = "Renta", inplace = True)
Sexo
# Out:
#     Renta     Sexo
# 12      0  Mujeres
# 13    150  Mujeres
# 11    350  Mujeres
# 7     600  Mujeres
# 10    788  Mujeres
# 0     800  Hombres
# 6     800  Mujeres
# 9     900  Mujeres
# 3    1200  Hombres
# 5    1200  Hombres
# 8    1200  Mujeres
# 2    1600  Hombres
# 1    5000  Hombres
# 4   12000  Hombres

# %%
# 7°) Creamos una variable Rango, para el orden de la Renta --->

Sexo["Rango"] = range(1, len(Sexo) + 1)
Sexo
# Out:
#     Renta     Sexo  Rango
# 12      0  Mujeres      1
# 13    150  Mujeres      2
# 11    350  Mujeres      3
# 7     600  Mujeres      4
# 10    788  Mujeres      5
# 0     800  Hombres      6
# 6     800  Mujeres      7
# 9     900  Mujeres      8
# 3    1200  Hombres      9
# 5    1200  Hombres     10
# 8    1200  Mujeres     11
# 2    1600  Hombres     12
# 1    5000  Hombres     13
# 4   12000  Hombres     14

# %%
# 8°) Creamos un DataFrame para calcular la MEDIA(promedio) de los datos que se repiten en la renta(800-800)
# para promediarlas en 6.5 --->

rango = Sexo[["Renta", "Rango"]].groupby(["Renta"]).mean()
rango
# Out:
#        Rango
# Renta
# 0        1.0
# 150      2.0
# 350      3.0
# 600      4.0
# 788      5.0
# 800      6.5
# 900      8.0
# 1200    10.0
# 1600    12.0
# 5000    13.0
# 12000   14.0

# %%
# 9°) Sacamos la RENTA que aparece como INDICE, en el cuadro anterior y luego colocamos rango como
# una variable --->

rango.reset_index(inplace = True)
rango
# Out:
#     Renta  Rango
# 0       0    1.0
# 1     150    2.0
# 2     350    3.0
# 3     600    4.0
# 4     788    5.0
# 5     800    6.5
# 6     900    8.0
# 7    1200   10.0
# 8    1600   12.0
# 9    5000   13.0
# 10  12000   14.0

# %%
# 10°) Como el arcchivo de SEXO contiene RANGO y el de RENTA tambien, solo nos quedaremos con el RANGO de RENTA
# entonces lo quitamos del archivo de SEXO --->

Sexo.drop(["Rango"], axis = 1, inplace = True)
Sexo
# Out:
#     Renta     Sexo
# 12      0  Mujeres
# 13    150  Mujeres
# 11    350  Mujeres
# 7     600  Mujeres
# 10    788  Mujeres
# 0     800  Hombres
# 6     800  Mujeres
# 9     900  Mujeres
# 3    1200  Hombres
# 5    1200  Hombres
# 8    1200  Mujeres
# 2    1600  Hombres
# 1    5000  Hombres
# 4   12000  Hombres

# %%
# 11°) Ahora pegamos ese archivo SEXO en RANGO con MARGE usando la variable RENTA --->
import pandas as pd
Sexo = Sexo.merge(rango, left_on = "Renta", right_on = "Renta", how = "left")
Sexo
# Out:
#     Renta     Sexo  Rango
# 0       0  Mujeres    1.0
# 1     150  Mujeres    2.0
# 2     350  Mujeres    3.0
# 3     600  Mujeres    4.0
# 4     788  Mujeres    5.0
# 5     800  Hombres    6.5
# 6     800  Mujeres    6.5
# 7     900  Mujeres    8.0
# 8    1200  Hombres   10.0
# 9    1200  Hombres   10.0
# 10   1200  Mujeres   10.0
# 11   1600  Hombres   12.0
# 12   5000  Hombres   13.0
# 13  12000  Hombres   14.0

# %% [markdown]
# <font color='orange'>$R_1$: suma de los rangos del grupo $n_1$ (hombres) \\
# <font color='orange'>$R_2$: suma de los rangos del grupo $n_2$ (mujeres)

# %%
# 12°) Calculamos las sumas de los rangos por Sexo --->

Temp = Sexo[["Sexo", "Rango"]].groupby("Sexo").sum()
Temp
# Out:
#          Rango
# Sexo
# Hombres   65.5
# Mujeres   39.5

# %%
# 13°) Extraemos cada uno de ellos --->

R_1 = Temp.loc["Hombres"][0] # R_1 rango de hombres , .LOC extrae.
R_1
# Out:
# 65.5

# %%
R_2 = Temp.loc["Mujeres"][0] # R_2 rango de mujeres
R_2
# Out:
# 39.5

# %% [markdown]
# <font color='orange'>Calculando  $u = min(u_1, u_2)$
# >- $u_1 = n_1 \times n_2 + \frac{n_1 \times (n_1 + 1)}{2} - R_1$
# >- $u_2 = n_1 \times n_2 + \frac{n_2 \times (n_2 + 1)}{2} - R_2$

# %%
# 14°)
u_1 = n_1 * n_2 + (n_1 * (n_1 + 1)) / 2 - R_1
u_1
# Out:
# 3.5

# %%
u_2 = n_1 * n_2 + (n_2 * (n_2 + 1)) / 2 - R_2
u_2
# Out:
# 44.5

# %%
u = min(u_1, u_2)
u
# Out:
# 3.5

# %% [markdown]
# <font color='orange'>**Calculando**
# $$\mu{(u)} = \frac{n_1 \times n_2}{2}$$

# %%
# 15°)
mu_u = (n_1 * n_2) / 2
mu_u

# Calculamos la MEDIA de U
# Out:
# 24.0

# %% [markdown]
# <font color='orange'>Calculando
# $$\sigma{(u)} = \sqrt{\frac{n_1 \times n_2 \times (n_1 + n_2 + 1)}{12}}$$

# %%
# 16°) Calculando la Desviacion Estandar --->

Sigma_u = np.sqrt((n_1 * n_2 * (n_1 + n_2 + 1)) / 12)
Sigma_u
# Out:
# 7.745966692414834

# %% [markdown]
# <font color='orange'>Calculamos
# $$Z = \frac{u - \mu{(u)}}{\sigma{(u)}}$$

# %%
# 17°) Calculamos la ESTADISTICA DE PRUEBA --->

Z = (u - mu_u) / Sigma_u
Z
# Out:
# -2.6465386199084016

# %%
Z.round(2)
# Out:
# -2.65

# %% [markdown]
# <font color='orange'> Paso 4: Determinar la región crítica

# %% [markdown]
# ![Region Critica Salario](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_Salario.png)

# %% [markdown]
# <font color='orange'> Obteniendo $z_\alpha$

# %%
# 18°) Importamos NORM --->
from scipy.stats import norm

# %%
# 19°) El area que tenemos calculado hasta ese valor es del 0.05%, calculamos alpha --->

z_alpha = norm.ppf(0.05)
z_alpha
# Nos devuelve el VALOR CRITICO
# Out:
# -1.6448536269514729

# %% [markdown]
# ![Valor Critico Salario](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Valor_Critico_Salario.png)

# %% [markdown]
# <font color='orange'> **Paso 5: Tomar la decisión y concluir**

# %% [markdown]
# <font color='red'>¿$Z = -2,65$ está en la Región Crítica?</font> o equivalentemente <font color='red'> ¿ $Z \geq 1,64$ o $Z \leq -1,64$?</font>

# %%
# 20°)
Z <= z_alpha

# NOS DEVUELVE TRUE, SUFICIENTE EVIDENCIA PARA RECHAZAR Ho, EXISTE DESIGUALDAD EN EL SALARIO ENTRE HOMBRES Y MUJERES,
# LAS MUJERES GANAN MENOS
# Out:
# True

# %% [markdown]
# Observe que $Z\leq -1,64$ y por lo tanto hay suficiente evidencia en la muestra para rechazar $H_0$.

# %% [markdown]
# ![Decision Salario](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Decision_Salario.png)

# %% [markdown]
# <font color='orange'> **CRITERIO DE P_VALOR**
#
# <font color='red'>Rechazamos $H_0$ si $p$-valor $\leq \alpha$.</font>

# %% [markdown]
# Recordemos que cuando la prueba es unilateral a izquierda $(H_1: \mu_{m} < \mu_{h})$ el $p$-valor se calcula como
#
# $$p-\textrm{valor}= P(W \leq Z)$$

# %%
# 1°) Importamos NORM --->
from scipy.stats import norm

# %%
# 2°) Calculamos el valor acumulado hasta Z que ya fue calculado (-2.65) --->
p_val = norm.cdf(0.05)
p_val
# Out:
# 0.5199388058383725

# %%
# 3°) Ahora vemos si el P_VALOR es menor o igual a SIGNIFICANCIA --->

p_value <= significancia
# Out:
# True

# %% [markdown]
# <font color='blue'>**Conclusión:** Rechazamos la hipótesis de que no existe diferencia entre los dos grupos, por lo tanto concluimos que el ingreso promedio de las mujeres jefas de hogar es menor que el ingreso promedio de los hombres jefes de hogar. Esto confirma la alegación de la desigualdad de ingresos entre los sexos.</font>

# %% [markdown]
#  #### <font color='orange'> Usando biblioteca de Phyton ( FORMA AUTOMATICA)
#
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html

# %%
# 1°) Importamos la FUNCION MANNWHITENEYU de la biblioteca SCIPY --->
from scipy.stats import mannwhitneyu

# %%
# 2°) Al acumulado le calsculamos las 2 MUESTRAS --->

mannwhitneyu(muestra_mujeres, muestras_hombres, alternative="less") # lees , < unilateral a la izquierda
# Out:
# MannwhitneyuResult(statistic=755.0, pvalue=0.0012458586184933508)

# %%
# 3°) Los separamos --->

u, p_value = mannwhitneyu(muestra_mujeres, muestra_hombres, alternative="less")
print(u)
print(p_value)
# Out:
# 3.5
# 0.004711774430622195

# %%
# 4°) Comparamos el P_value con significancia --->

p_value <= significancia

# ES MENOR MISMO RESULTADO QUE FORMA MANUAL, PERO MAS RAPIDO Y FACIL.
# Out:
# True

# %% [markdown]
# <font color='blue'>**Conclusión:** Rechazamos la hipótesis de que no existe diferencia entre los dos grupos, por lo tanto concluimos que el ingreso promedio de las mujeres jefas de hogar es menor que el ingreso promedio de los hombres jefes de hogar. Esto confirma la alegación de la desigualdad de ingresos entre los sexos.</font>

# %% [markdown]
# ### <font color='orange'> **Generalizando**

# %% [markdown]
# #### **Hipótesis**
# > Prueba <font color ='red'> bilateral </font> $\hspace{2.3 cm}$
# $
# \begin{cases}
# H_0: \mu_1 = \mu_2\\
# H_1: \mu_1 \neq \mu_2
# \end{cases}
# $
#
# > Prueba  <font color ='red'>Unilateral a derecha</font>$\hspace{0.2 cm}$
# $
# \begin{cases}
# H_0: \mu_1 \leq \mu_2\\
# H_1: \mu_1 > \mu_2
# \end{cases}
# $
#
# > Prueba <font color ='red'> Unilateral a Izquierda </font>
# $
# \begin{cases}
# H_0: \mu_1 \geq \mu_2\\
# H_1: \mu_1 < \mu_2
# \end{cases}
# $

# %% [markdown]
# #### <font color='orange'> **Estadística de prueba**
# La estadística de la prueba es
#
# $$Z = \frac{u - \mu{(u)}}{\sigma{(u)}} \stackrel{aprox}{\sim} N(0,1),$$
#
# donde
#
# > $u = min(u_1, u_2)$
# >- $u_1 = n_1 \times n_2 + \frac{n_1 \times (n_1 + 1)}{2} - R_1$
# >- $u_2 = n_1 \times n_2 + \frac{n_2 \times (n_2 + 1)}{2} - R_2$
# >- $n_1$ = nº de elementos del grupo mas pequeño (hombres)
# >- $n_2$ = nº de elementos del grupo más grande (mujeres)
# >- $R_1$ = suma de los rangos del grupo $n_1$
# >- $R_2$ = suma de los rangos del grupo $n_2$
#
# $u \stackrel{aprox}{\sim} N\left(\mu(u), \sigma(u)\right)$
#
# > $\mu{(u)} = \frac{n_1 \times n_2}{2}$
#
# > $\sigma{(u)} = \sqrt{\frac{n_1 \times n_2 \times (n_1 + n_2 + 1)}{12}}$

# %% [markdown]
# ####<font color='orange'>  **Región Crítica**

# %% [markdown]
# ![Region Critica NP](https://caelum-online-public.s3.amazonaws.com/ESP-1778-estadistica-con-python-test-hipotesis/Region_Critica_NP.png)

# %% [markdown]
# #### <font color='orange'> **$p$-valor**

# %% [markdown]
# Asumiendo que $W$ es una estadística de prueba  cualquiera (calculada bajo $H_0$ cierta), el $p$-valor es calculado como sigue:
#
# >- Prueba <font color='red'>bilateral $(H_1: \mu_{1} \neq \mu_{2})$</font>
#
# $$p-\textrm{valor}= 2\times P(W \geq Z) = 2\times [1-P(W < Z) ] $$.
#
# >- Prueba <font color='red'>Unilateral a derecha $(H_1: \mu_{1} > \mu_{2})$</font>
#
# $$p-\textrm{valor}= P(W \geq Z)= 1-P(W < Z)$$
#
# >- Prueba <font color='red'>Unilateral a izquierda $(H_1: \mu_{1} < \mu_{2})$</font>
#
# $$p-\textrm{valor}= P(W \leq Z)$$.

# %%
# EJEMPLO AULA --->

# Un docente cree que los alumnos que practican ejercicios físicos tienen un rendimiento escolar medio superior al obtenido por
# los alumnos que no lo hacen. Para probar su teoría, seleccionó dos muestras aleatorias, una con 9 estudiantes que no hacen
# ejercicio y la otra con 10 estudiantes que cultivan el hábito de hacer ejercicio. La siguiente tabla muestra las calificaciones
# de los estudiantes en el último año:

# Sin ejercicios	Con ejercicios
#      7	             8
#      6	             7
#      7	             6
#      8	             6
#      6	             8
#      8	             6
#      6	             10
#      9	             6
#      5	             7
#                      8

# Pruebe la hipótesis de que las calificaciones promedio de los estudiantes que hacen ejercicio son más altas que las calificaciones
# promedio de los estudiantes que no hacen ejercicio. Marque la alternativa que presenta el resultado de la prueba (estadística de prueba u y decisión de prueba).
# Considere un nivel de significancia del 10%.

from scipy.stats import mannwhitneyu
Sin_Ejercicios = pd.Series([7, 6, 7, 8, 6, 8, 6, 9, 5])
Con_Ejercicios = pd.Series([8, 7, 6, 6, 8, 6, 10, 6, 7, 8])
significancia = 0.10
u, p_valor = mannwhitneyu(Sin_Ejercicios, Con_Ejercicios, alternative='less')
print('u =', u)
if(p_valor <= significancia):
  print('Rechace H0')
else:
  print('No rechace H0')

# u=40
# No rechace H_0, es decir, no tenemos suficiente evidencia en las muestras para decir que el rendimiento escolar medio de los
# alumnos que practican ejercicios físicos es superior al de los alumnos que no practican ejercicios físicos.
# Out:
# u = 40.0
# No rechace H0
